# %% [markdown]
# #**Installing the required dependencies**

# %%
# %%capture
# !git clone https://github.com/AI4Bharat/IndicTrans2.git

# %%
# %%capture
# %cd /content/IndicTrans2/huggingface_interface

# %%
# %%capture
# !python3 -m pip install nltk sacremoses pandas regex mock transformers>=4.33.2 mosestokenizer
# !python3 -c "import nltk; nltk.download('punkt')"
# !python3 -m pip install bitsandbytes scipy accelerate datasets
# !python3 -m pip install sentencepiece

# !git clone https://github.com/VarunGumma/IndicTransTokenizer
# %cd IndicTransTokenizer
# !python3 -m pip install --editable ./
# %cd ..

# %% [markdown]
# **IMPORTANT : Restart your run-time first and then run the cells below.**

# %% [markdown]
# ## 1. Importing the requried libraries:
#   * transformer
#   * torch
#   * AutoModelForSeq2SeqLM from transformer
#   * BitsAndBytesConfig from transformer
#   * IndicProcessor from from IndicTransTokenizer
#   * IndicTransTokenizer from IndicTransTokenizer

# %%
import transformers
import torch
from transformers import AutoModelForSeq2SeqLM, BitsAndBytesConfig
from transformers import AutoTokenizer
from IndicTransTokenizer import IndicTransTokenizer, IndicProcessor

# %%
BATCH_SIZE = 4
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
QUANTIZATION = None

# %% [markdown]
# #**Setting up the model initializer and tokenizer function.
# .**
#
# Create a function initialize_model_and_tokenizer which takes in 4 arguments: ckpt_dir, direction, quantization.
# Inside the function, if quantization  = '4-bit' then create a variable qconfig and use appropriate BitsAndByteConfig to instantiate it. Else if quantization  = '8-bit', then do the necessary. Else, set it to None.
#
# (To learn more, check out the documentation on [BitsAndByteConfig](https://huggingface.co/docs/transformers/en/main_classes/quantization#transformers.BitsAndBytesConfig).)
#
# After the conditional flow, create a variable tokenizer
#
# The next step involves making a model variable. Set it to AutoModelForSeq2SeqLM, which should load the pre-trained model from the checkpoint directory.

# %%
def initialize_model_and_tokenizer(ckpt_dir, direction, quantization):
    """
    Initializes and returns a model and tokenizer for sequence-to-sequence language modeling.

    Args:
        ckpt_dir (str): The directory path of the pre-trained model checkpoint.
        direction (str): The translation direction for the tokenizer (e.g., 'en-hi' for English to Hindi).
        quantization (str): The quantization level for the model.
                            Should be '4-bit', '8-bit', or None for no quantization.

    Returns:
        tuple: A tuple containing:
            - tokenizer: The tokenizer initialized with the specified direction.
            - model: The sequence-to-sequence model loaded with the specified configurations.
    """
    if quantization == '4-bit':
        qconfig = BitsAndBytesConfig(load_in_4bit=True)
    elif quantization == '8-bit':
        qconfig = BitsAndBytesConfig(load_in_8bit=True)
    else:
        qconfig = None  # No quantization applied


    tokenizer = IndicTransTokenizer(direction)

    model = AutoModelForSeq2SeqLM.from_pretrained(
        ckpt_dir,
        trust_remote_code=True,
        low_cpu_mem_usage=True,
        quantization_config=qconfig
    )

    if qconfig is None:
        model = model.to(DEVICE)
        if DEVICE == "cuda":
            model.half()

    model.eval()
    return tokenizer, model

# %% [markdown]
# #**Helper Function to Batch Translation**
#
# This function translates a group of sentences from one language to another using a pre-trained model. It allows you to efficiently process multiple sentences at once, converting them from the source language to the target language.

# %%
def batch_translate(input_sentences, src_lang, tgt_lang, model, tokenizer, ip):
    """
    Translates a batch of input sentences from the source language to the target language using a pre-trained model.

    Args:
        input_sentences (list of str): The list of sentences to translate.
        src_lang (str): The source language code (e.g., 'en' for English).
        tgt_lang (str): The target language code (e.g., 'hi' for Hindi).
        model (torch.nn.Module): The pre-trained sequence-to-sequence model for translation.
        tokenizer (transformers.PreTrainedTokenizer): The tokenizer corresponding to the model.
        ip (object): An instance of a class with methods for preprocessing and postprocessing batches.

    Returns:
        list of str: A list of translated sentences in the target language.
    """

    translations = []

    for i in range(0, len(input_sentences), BATCH_SIZE):
        batch = input_sentences[i : i + BATCH_SIZE]

        batch = ip.preprocess_batch(batch, src_lang=src_lang, tgt_lang=tgt_lang)

        inputs = tokenizer(
            batch,
            src=True,
            truncation=True,
            padding="longest",
            return_tensors="pt",
            return_attention_mask=True
        ).to(DEVICE)

        with torch.no_grad():
            generated_tokens = model.generate(
                **inputs,
                use_cache=True,
                min_length=0,
                max_length=256,
                num_beams=5,
                num_return_sequences=1,
            )

        generated_tokens = tokenizer.batch_decode(
            generated_tokens.detach().cpu().tolist(),
            src=False
        )

        translations += ip.postprocess_batch(generated_tokens, lang=tgt_lang)

        del inputs
        torch.cuda.empty_cache()

    return translations

# %%
ckpt_dir = "ai4bharat/indictrans2-indic-indic-1B"

direction = "indic-indic"

quantization = None

tokenizer, model = initialize_model_and_tokenizer(ckpt_dir, direction, quantization)

ip = IndicProcessor(inference=True)
# Out:
# <ipython-input-6-7db3135325bc>:26: DeprecationWarning: This IndicTransTokenizer is deprecated.
# The official Tokenizer is available on HF and can be used as follows:
# ```
# from transformers import AutoTokenizer
# tokenizer = AutoTokenizer.from_pretrained(model_name)
# ```
#   tokenizer = IndicTransTokenizer(direction)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.36k [00:00<?, ?B/s]
# configuration_indictrans.py:   0%|          | 0.00/14.2k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/ai4bharat/indictrans2-indic-indic-1B:
# - configuration_indictrans.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_indictrans.py:   0%|          | 0.00/79.6k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/ai4bharat/indictrans2-indic-indic-1B:
# - modeling_indictrans.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# pytorch_model.bin:   0%|          | 0.00/4.83G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/168 [00:00<?, ?B/s]

# %%
# %%capture
# !pip install sacrebleu rouge_score

# %%
# %%capture
# download the evaluate dataset and unzip it
# !wget https://indictrans2-public.objectstore.e2enetworks.net/IN22_testset.zip && unzip IN22_testset.zip

# %%
input_sent = []

with open('IN22_testset/conv/test.ben_Beng', 'r') as f:
    for line in f:
        input_sent.append(line)

# %%
src_lang, tgt_lang = "ben_Beng", "mai_Deva"

batch = ip.preprocess_batch(
    input_sent,
    src_lang=src_lang,
    tgt_lang=tgt_lang,
)

mai_sent = batch_translate(input_sent, src_lang, tgt_lang, model, tokenizer, ip)
for i in range(len(input_sent)):
    print(input_sent[i])
    print(mai_sent[i])
    print()
# Out:
# Streaming output truncated to the last 5000 lines.
#
# কিন্তু ম্যাম, গঙ্গা আর ব্রহ্মপুত্র দুটোই কি করে ভারতের দীর্ঘতম নদী হতে পারে?
#
# परंच मैम, गंगा आ ब्रह्मपुत्र दुनू भारतक सबसँ लम्बा नदी केना भऽ सकैत अछि?
#
# ব্রহ্মপুত্র তো স্পষ্টতই গঙ্গার থেকে দীর্ঘতর।
#
# ब्रह्मपुत्र स्पष्ट रूपसँ गङ्गासँ पैघ अछि।
#
# গঙ্গা দীর্ঘতম হলেও জলপ্রবাহের নিরিখে ব্রহ্মপুত্র হলো বৃহত্তম।
#
# यद्यपि गङ्गा सभसँ नमगर अछि मुदा ब्रह्मपुत्र जल प्रवाहक हिसाबसँ सभसँ पैघ अछि।
#
# 'দক্ষিণ গঙ্গা' নামেও পরিচিত গোদাবরী হলো গঙ্গার পরে দ্বিতীয় দীর্ঘতম এবং দক্ষিণ ভারতের দীর্ঘতম নদী।
#
# गोदावरी, जकरा दक्षिण गङ्गा सेहो कहल जाइत अछि, गङ्गाक बाद दोसर सभसँ नमगर आ दक्षिण भारतक सभसँ नमगर नदी अछि।
#
# হিন্দু ধর্মগ্রন্থে বহু সহস্র কাল ধরে সম্মানিত এবং সমৃদ্ধ সাংস্কৃতিক ঐতিহ্যের ধারক ও বাহক হয়ে আছে নদীটি।
#
# ई नदी हिन्दू धर्मग्रंथमे कतेको सहस्राब्दीसँ सम्मानित आ समृद्ध सांस्कृतिक धरोहरक धारक आ वाहक रहल अछि।
#
# এবং কৃষ্ণা-গোদাবরী অববাহিকা হলো বিপন্ন অলিভ রিডলি কাছিমের ডিম পাড়ার প্রধান স্থানগুলির মধ্যে অন্যতম।
#
# आ कृष्णा-गोदावरी बेसिन लुप्तप्राय ऑलिव रिडले कछुवाक लेल अंडा देबाक प्रमुख स्थानसभमे सँ एक अछि।
#
# একদমই তাই।
#
# ठीक अछि, ठीक अछि।
#
# নদী সম্পর্কে তোমার বিস্তারিত ধারণা দেখে আমি সত্যিই খুশি হয়েছি।
#
# नदीक विषयमे अहाँक विस्तृत विचार देखि हमरा बड्ड खुशी भेल।
#
# ধন্যবাদ ম্যাম, বেশিরভাগই আপনি আমাদের আগের ক্লাসে পড়িয়েছেন।
#
# धन्यवाद मैम, अधिकतर जे अहाँ हमरा सभकेँ पहिनेक कक्षामे पढ़ौने छलहुँ।
#
# আর পরেরটায় আমরা আরও কিছু শিখবো।
#
# आ अगिला मे हम सभ आओर किछु सीखब।
#
# সময় শেষ! কাল দেখা হবে, বাচ্চারা!
#
# समय खतम भऽ गेल अछि! हम अगिला दिन भेँट करब, बच्चासभ!
#
# হ্যালো, তোমাকে চিন্তিত মনে হচ্ছে, কি ব্যাপার?
#
# नमस्कार, अहाँ चिन्तित प्रतीत होइत छी, की बात अछि?
#
# হ্যাঁ, কয়েক ঘণ্টা ধরে ওড়িশার ঘূর্ণিঝড়ের সাম্প্রতিক খবরগুলো দেখছিলাম।
#
# हँ, हम किछु घण्टासँ ओडिशामे चक्रवातक हालक समाचार देख रहल छलहुँ।
#
# আজ ঘূর্ণিঝড়ের দ্বিতীয় দিন, আর পুরো শহরটাই বিপর্যস্ত হয়ে পড়েছে।
#
# आइ चक्रवातक दोसर दिन अछि आ पूरा शहर तहस-नहस भऽ गेल अछि।
#
# এমনকি মৌলিক সুবিধাগুলোর জন্য বাইরে বেরনো অবধি কঠিন হয়ে পড়েছে।
#
# एतऽ धरि कि बुनियादी सुविधाक लेल बाहर निकलैत सेहो कठिन भऽ गेल अछि।
#
# সৌভাগ্যবশত আমাদের পাড়ায় এখনও পর্যন্ত বিদ্যুৎ আছে, তবে বেশিরভাগ অঞ্চলই বিদ্যুৎবিহীন।
#
# सौभाग्यसँ हमर लगपासमे एखन धरि बिजली अछि, मुदा अधिकांश क्षेत्रमे बिजली नहि अछि।
#
# শুনে আমার খুব খারাপ লাগছে, আশা করি তুমি ও তোমার পরিবার সুরক্ষিত আছো।
#
# हमरा बड्ड दुख भऽ रहल अछि, आशा अछि जे अहाँ आ अहाँक परिवार सुरक्षित रहब।
#
# এটা কতক্ষণ চলতে পারে সে সম্বন্ধে তোমার কোনও ধারণা আছে?
#
# की अहाँकेँ कोनो जानकारी अछि जे ई कतेक समय धरि चलि सकैत अछि?
#
# আবহাওয়ার আগের পূর্বাভাস এবং সর্বশেষ খবর অনুযায়ী, প্রায় ৩ দিন ধরে চলবে এটা।
#
# पूर्व मौसम पूर्वानुमान आ नवीनतम खबरक अनुसार, ई लगभग 3 दिन धरि चलत।
#
# কিন্তু আমি যদিও বেশি চিন্তিত এর পরিণতি নিয়ে।
#
# मुदा हम परिणामसँ बेसी चिन्तित छी।
#
# শেষবার ২০২০-তে দু'দিন ধরে চলা ঘূর্ণিঝড়ের পরে কিছু এলাকায় বিদ্যুৎ আসতে ১৫ দিন অবধি লেগে গিয়েছিল।
#
# अन्तिम बेर 2020 मे दू दिन धरि चलैत चक्रवातक बाद किछु क्षेत्रमे बिजली अयबामे 15 दिन तकक समय लागि गेल छल।
#
# যখনই কোনোরকম প্রাকৃতিক দুর্যোগ ঘটেছে, ওড়িশায় এই ধরনের ক্ষয়ক্ষতির প্রবণতা দেখা গেছে।
#
# ओडिशामे जखन-जखन कोनो प्राकृतिक आपदा होइत अछि तखन एहन क्षतिक प्रवृत्ति देखल जाइत अछि।
#
# ২০২০-তে তো তুমি ওড়িশায় এসেছিলে, ঘূর্ণিঝড়ের সময় ছিলে?
#
# की अहाँ 2020 मे ओडिशा आयल छलहुँ, चक्रवातक समय?
#
# না, সৌভাগ্যবশত ঘূর্ণিঝড়ের ঠিক এক সপ্তাহ আগেই আমি চলে গিয়েছিলাম।
#
# नहि, सौभाग्यसँ हम बवंडरक ठीक एक सप्ताह पहिने चलि गेलाह।
#
# এরকম একটা বিধ্বংসী ব্যাপার এখানে বসবাসকারী মানুষের জন্য কেমন হতে পারে তাই ভাবি!
#
# सोचू कि एहि ठाम जे लोक रहैत छथि हुनका लेल ई कतेक विनाशकारी बात भऽ सकैत अछि!
#
# বিশেষত, উপকূলের কাছাকাছি থাকা লোকজন।
#
# विशेष रूपसँ ओ लोक जे तटक निकट रहैत छथि।
#
# বাড়িঘর আর জীবিকা পুনর্বাসনে সরকার কি এদের সাহায্য করে?
#
# की सरकार हुनका घर आ आजीविका के पुनर्वास मे मदद करैत अछि?
#
# বছরের পর বছরের খাটনি এক-দু'দিনের মধ্যে নষ্ট হওয়াটা নিশ্চয়ই ভয়ানক।
#
# एक-दू दिनमे बरख-बरख धरि खुजल-खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल खुजल
#
# সরকার তার সাধ্যমতো সাহায্য অবশ্যই করে, বিশেষত গ্রামাঞ্চলে, যেখানে মানুষ নিজেদের সংস্থান নিজেরাই ঘটায়।
#
# सरकार विशेष रूपसँ ग्रामीण क्षेत्रमे यथासम्भव सहायता अवश्य करैत अछि, जतय लोक अपन संसाधन स्वयं बनबैत छथि।
#
# কাজের গতি বাড়াতে গতবার ভিন্ রাজ্য থেকে কর্মী আনা হয়েছিল।
#
# काजकेँ तेज करबाक लेल पिछला बेर विन राज्यसँ कर्मचारी आनल गेल छल।
#
# বহু অসুবিধার শিকার হওয়া শিশু ও বয়স্ক মানুষদের জন্য ঠিক সময়ে বিদ্যুৎ সংযোগ ফিরিয়ে আনতে পৌর নিগমের কর্মীরাও এমনকি দিনরাত এক করে কাজ করেছে।
#
# नगर निगमक कर्मचारी दिन-राति एक-एक कऽ बच्चा आ बुजुर्ग लोकक लेल समय पर बिजली बहाल करबाक लेल काज सेहो कयलनि, जे बहुत कठिनाइक सामना कऽ रहल छलाह।
#
# এই সময়গুলোতে চরম আবহাওয়া পরিস্থিতির সম্মুখীন হওয়া স্থানগুলোর মধ্যে ওড়িশা একটা।
#
# ओडिशा ओहि स्थान सभमेसँ एक अछि जतय एहि अवधिमे चरम मौसमी स्थितिक अनुभव होइत अछि।
#
# নাগরিকরা সময়মতো সাহায্য পান জেনে ভালো লাগলো।
#
# ई जानि नीक लागि रहल अछि जे नागरिकसभकेँ समय पर सहायता भेट रहल अछि।
#
# এইরকম চরম আবহাওয়া পরিস্থিতির কারণে কীরকম সাঙ্ঘাতিক অবস্থা হতে পারে তা দেখাটাও দুর্ভাগ্যজনক।
#
# ई देखनाइ सेहो दुर्भाग्यपूर्ण अछि जे एहन चरम मौसमक स्थिति कतेक गम्भीर भऽ सकैत अछि।
#
# তুমি সেখানে কবে থেকে থাকো?
#
# अहाँ ओतऽ कखन रहलहुँ?
#
# জলবায়ুর রকমফের তোমাকে কখনও রাজ্য ছেড়ে আসতে অনুপ্রাণিত করেছে?
#
# की अहाँ कहियो जलवायु परिवर्तनसँ राज्य छोड़बाक लेल प्रेरित भेल छी?
#
# পাঁচ বছর হয়ে গেলো আমি এখানে আছি।
#
# पाँच साल भऽ गेल अछि जखन हम एतऽ आयल छी।
#
# গ্রীষ্মকালটায় গরম আর আর্দ্রতা বেশ ভালোরকম থাকলেও অন্যান্য দিক থেকে আবহাওয়া ভালো হওয়ার কারণে ছেড়ে যাওয়ার কথা কখনও ভাবিনি।
#
# गर्मीमे गर्मी आ आर्द्रता नीक रहैत अछि, मुदा दोसर दिससँ नीक मौसमक कारणेँ कहियो छोड़ि देबाक विचार नहि कयलहुँ।
#
# বর্ষাকালটা একটু কঠিন মনে হলেও এত বছরে সেটা গা-সওয়া হয়ে গেছে।
#
# मानसूनक मौसम किछु कठिन लगैत अछि, मुदा एते वर्षमे ई कम भऽ गेल अछि।
#
# আচ্ছা, এটা সয়ে যাওয়ার মতোই মনে হচ্ছে; খুব তাড়াতাড়ি পরিস্থিতি আরও ভালো হয়ে উঠুক এটুকুই আশা রাখি।
#
# ठीक अछि, एना लगैत अछि जे ई समाप्त भऽ गेल अछि; बस आशा करैत छी जे जल्दी सँ जल्दी सब ठीक भऽ जाय।
#
# সরি, আমাকে যেতে হবে, চট করে ঘূর্ণিঝড়ের সাম্প্রতিক খবরটা দিতে পারো?
#
# क्षमा करू, हमरा जयबाक अछि, की अहाँ बवंडरक हालक समाचार दऽ सकैत छी?
#
# বর্তমান পরিস্থিতি আর এই মুহূর্তে কীভাবে সবাই সেটার মোকাবিলা করছে।
#
# वर्तमान स्थिति आ एहि समय सभ एकरा कोना सँभाल रहल अछि।
#
# সবার জন্য মুদির জিনিসপত্র, চিকিৎসার সুযোগ-সুবিধা, ওষুধ আর সবরকম প্রয়োজনীয় জিনিস নিয়ে সাহায্যের জন্য এখানকার অনেকগুলি সংস্থা এগিয়ে এসেছে।
#
# एतऽ के बहुत रास संगठन सब के लेल किराना सामान, चिकित्सा सुविधा, दवाई आ सब आवश्यक चीज के मदद करै लेल आगू आयल अछि।
#
# প্রয়োজনমতো সাহায্যের জন্য বেশীরভাগ এলাকায় দলও গঠন করা হয়েছে।
#
# आवश्यकता पड़ला पर सहायता प्रदान करबाक लेल अधिकांश क्षेत्रमे टीमक गठन सेहो कयल गेल अछि।
#
# তবে ধৈর্য্য ধরে থাকা আর একে অপরকে সাহায্য করা ছাড়া আমাদেরও আর বিশেষ কিছু করার নেই।
#
# मुदा हमरा सभ लग धैर्य रखबाक आ एक दोसराक सहायता करबाक अतिरिक्त किछु खास नहि अछि।
#
# হ্যাঁ, তা ঠিক!
#
# हँ, ठीक अछि!
#
# তোমরা সবাই নিজেদের আর একে অপরের খেয়াল রেখো।
#
# अहाँ सभ अपन-अपन आ एक-दोसराक देखभाल करू।
#
# আশা করি সব খুব তাড়াতাড়ি ঠিক হয়ে যাবে; এখান থেকে আমার করার মতো কিছু থাকলে আমাকে জানিও।
#
# आशा अछि जे सब किछु जल्दी ठीक भऽ जायत; हमरा बताउ यदि हमरा एतऽसँ किछु करबाक अछि।
#
# নিশ্চয়ই, আমি তোমাকে অবশ্যই জানাবো।
#
# बेशक, हम अहाँ केँ जरूर बता देब।
#
# অবশেষে, আনলক পর্ব শুরু হলো।
#
# अन्तमे अनलॉकिंगक चरण शुरू भऽ गेल।
#
# আর কোনও কঠিন নিষেধাজ্ঞা নেই।
#
# आओर कोनो कठोर प्रतिबन्ध नहि अछि।
#
# আমি বোধয় উন্মাদ হয়ে যেতাম যদি আমায় আরও একটা সপ্তাহ বাড়ির মধ্যে থাকতে হতো।
#
# जँ हमरा एक सप्ताह आओर घरक भीतर रहबाक होनि तँ हमरा बड्ड पागलपन भऽ जायत।
#
# কে বলল তুমি নও?
#
# कोन कहलनि जे अहाँ नहि छी?
#
# আচ্ছা, মজা বাদ দাও, আনলক চালু হওয়া মানে এই নয় যে তুমি যা চাও তাই করতে পারবে।
#
# खैर, मौज-मस्ती छोड़ि दियौक, अनलक चालू होयबाक मतलब ई नहि अछि जे अहाँ जे किछु चाहैत छी से कऽ सकैत छी।
#
# রাতের কারফিউ এখনও চলবে।
#
# रातिमे कर्फ्यू एखनो जारी रहत।
#
# মাস্ক পড়ার বাধ্যতা এবং সামাজিক দূরত্বের নিয়ম এখনও প্রযোজ্য।
#
# मास्क पहिरबाक बाध्यता आ सामाजिक दूरीक नियम एखनो लागू अछि।
#
# এবং সব থেকে গুরুত্বপূর্ণ, টীকা নেওয়া নিয়ে আমাদের এই মুহূর্তে ভাবতে হবে।
#
# आ सबसँ महत्वपूर्ण बात ई अछि जे हमरा सभ केँ एखन टीका लगयबा पर विचार करय पड़त।
#
# ওহ, টীকা নেওয়াটা কি বাধ্যতামূলক?
#
# ओह, की टीका लगयबाक आवश्यकता अछि?
#
# আগে একবার কোভিডে আক্রান্ত হয়ে থাকলে সেই ব্যক্তির রোগটার প্রতি প্রতিরোধ গড়ে ওঠে না?
#
# पहिने एक बेर कोविडसँ संक्रमित भेलाक बाद की ओहि व्यक्तिकेँ एहि रोगक प्रति प्रतिरोधी नहि बनाओल जाइत अछि?
#
# হে ভগবান! কোথা থেকে এইসব ভুলভাল ধারণা পাও?
#
# हे भगवान! ई सब मूर्खतापूर्ण विचार कहाँसँ अबैत अछि?
#
# না, আগে একবার কোভিড হয়ে গিয়ে থাকলেও তার রোগের প্রতি প্রতিরোধ গড়ে ওঠে না।
#
# नहि, हुनका पहिने एक बेर कोविड भऽ चुकल अछि मुदा ओ एहि रोगक प्रति प्रतिरोधी नहि छथि।
#
# আসলে দুটোর মধ্যে কোনও সম্পর্কই নেই।
#
# असलमे दुनूमे कोनो सम्बन्ध नहि अछि।
#
# এবং সব থেকে জরুরী, টীকা নেওয়া একেবারে বাধ্যতামূলক।
#
# आ सबसँ जरूरी, टीका लगायब बिल्कुल अनिवार्य अछि।
#
# প্রত্যেককেই এই দুটো কোভিশিল্ড এবং কোভ্যাক্সিন নামে যাচাই করা টীকার যেকোনো একটা নিতে হবে।
#
# सभकेँ कोविशील्ड आ कोवैक्सिन नामक एहि दूटा सत्यापित टीकामे सँ कोनो एकटा लेबाक चाही।
#
# তার মানে তুমি বলতে চাইছ আমাকে গিয়ে প্রথমে টীকা নিতে হবে এবং তারপরে গিয়ে ভাবতে পারবো আনলকের সময় আমি কী কী করতে চাই।
#
# एकर मतलब अछि जे अहाँ कहैत छी जे हमरा पहिने जा कऽ टीका लगयबाक चाही आ फेर जा कऽ सोचबाक चाही जे अनलॉकिंगक समय हम की करय चाहैत छी।
#
# শুধু একটা নয়, একই টীকার দুটো ডোজ।
#
# न केवल एकटा बल्कि एकहि टीकाक दूटा खुराक।
#
# কোনও মলে ঢোকার আগে বা ট্রেন অথবা বিমানে যাত্রা করার আগে তোমাকে তোমার টীকাকরণের শংসাপত্রগুলো দেখাতে বলবে।
#
# मॉल मे प्रवेश करय सँ पहिने या ट्रेन या हवाई जहाज सँ यात्रा करय सँ पहिने अपन टीकाकरण प्रमाणपत्र देखाबय लेल कहू।
#
# সত্যি? তারা চাইবে? আমি কী করে এটার ব্যাপারে কিছুই জানিনা।
#
# वास्तवमे? ओ सभ चाहथि? हमरा एहि विषयमे किछु नहि बुझाइत अछि।
#
# এদিকে, আমি তো এই গরমকালে পরিবারের সঙ্গে ছুটি কাটাতে যাওয়ার পরিকল্পনা করছিলাম।
#
# एहि बीच हम एहि गर्मीमे परिवारक संग छुट्टी पर जयबाक योजना बना रहल छलहुँ।
#
# সেটার জন্য, তোমাদের সকলকে কোভিড-১৯ টীকার অন্তত প্রথম ডোজটা নিয়ে রাখতেই হবে।
#
# एकर लेल अहाँ सभकेँ कमसँ कम कोविड-19 टीकाक पहिल खुराक अवश्य लेबाक चाही।
#
# ঢোকার দরজাতেই তারা তোমাদের থেকে টীকাকরণের শংসাপত্র চাইবে।
#
# प्रवेश द्वार पर ओ सभ अहाँसँ टीकाकरणक प्रमाणपत्र माँगत।
#
# খবরের আপডেট সম্পর্কে দয়া করে সতর্ক থেকো।
#
# कृपया समाचार अपडेटक विषयमे सावधान रहू।
#
# হ্যাঁ ধন্যবাদ, এই পুরো সময়টা আমি অন্যরকম ভাবছিলাম।
#
# हँ, धन्यवाद, पूरा समय हम अलग-अलग सोच रहल छलहुँ।
#
# যত তাড়াতাড়ি সম্ভব আমি আমার ডোজটা নিয়ে নেব।
#
# हम जल्दीसँ जल्दी अपन खुराक लऽ लैत छी।
#
# হ্যাঁ দয়া করে নাও, আমাদের ভুলে যাওয়া উচিত নয় যে অতিমারী এখনও চলে যায়নি।
#
# हँ कृपया लऽ लिअ, हमरा सभकेँ ई नहि बिसरू जे महामारी एखन धरि नहि गेल अछि।
#
# আশা করি তুমি কোউইন ওয়েবসাইটে নিজেকে রেজিস্টার করে রেখেছ।
#
# आशा अछि जे अहाँ कोविन वेबसाइट पर अपना केँ पंजीकृत करा लेलहुँ अछि।
#
# হ্যাঁ আমি রেজিস্টার করেছি।
#
# हँ, हम पंजीकृत कयलहुँ अछि।
#
# তাহলে অনুগ্রহ করে টীকাকরণের একটা উপযুক্ত তারিখের খোঁজ করো আর সেটাকেই নির্ধারিত করো।
#
# एहिलेल कृपया टीकाकरणक लेल एकटा उपयुक्त तिथि ताकू आ ठीक ओही निर्धारित करू।
#
# তোমার টীকা নিয়ে এই সময়ে খুব জরুরী।
#
# एहि समय अपन टिप्पणी के बारे मे बहुत जरूरी अछि।
#
# আমি আজই এটা করে নেব।
#
# हम आइ ई करब।
#
# আমার ভুল ধারণা দূর করে দেওয়ার জন্য ধন্যবাদ।
#
# हमर गलत धारणाकेँ दूर करबाक लेल धन्यवाद।
#
# হ্যালো, স্যার, অভিযোগ কোথায় দায়ের করতে পারবো?
#
# नमस्कार, श्रीमान, हम शिकायत कतऽ कऽ सकैत छी?
#
# আপনার কী ধরনের অভিযোগ রয়েছে?
#
# अहाँक कोन-कोन प्रकारक शिकायत अछि?
#
# স্যার, আমাদের গ্রাম পরিষ্কার পানীয় জল পাচ্ছে না।
#
# श्रीमान, हमर गामकेँ स्वच्छ पेय जल नहि भेटैत अछि।
#
# সরকার পরিষ্কার জলের কথা দিয়েছে, কিন্তু আমরা আমাদের গ্রামে তা পাচ্ছি না।
#
# सरकार स्वच्छ जलक वचन देने अछि, मुदा हमसभकेँ अपन गाममे ई नहि भेट रहल अछि।
#
# আপনাদের গ্রামে এখনও পর্যন্ত কোনোও পরিদর্শন হয়নি?
#
# अहाँक गाम मे एखन धरि कोनो दौरा नहि भेल अछि?
#
# না স্যার, মাস পেরিয়ে গেছে কিন্তু তিনি আমাদের গ্রাম পরিদর্শনে আসেন নি।
#
# नहि सर, महीना बीत गेल अछि मुदा ओ हमर गाम नहि आयल छथि।
#
# আপনি কোন্ গ্রাম থেকে আসছেন?
#
# अहाँ कोन गामसँ आयल छी?
#
# স্যার, আমি মহুয়ারিয়া গ্রাম থেকে আসছি।
#
# श्रीमान, हम महुरिया गामसँ आयल छी।
#
# আর আপনাদের গ্রাম প্রধান কে?
#
# आ अहाँक गामक मुखिया कोन छथि?
#
# স্যার, আমিই ওখানকার গ্রাম প্রধান।
#
# श्रीमान, हम ओतऽ गामक मुखिया छी।
#
# আচ্ছা, স্যার, অনুগ্রহ করে আমাকে আপনার অভিযোগ সম্পর্কে বিস্তারিত বলুন।
#
# ठीक अछि, श्रीमान, कृपया हमरा अपन शिकायतक विवरण दियौक।
#
# আমি জল সরবরাহ বিভাগের কর্মকর্তার কাছে এটা পাঠিয়ে দেব।
#
# हम एकरा जल आपूर्ति विभागक अधिकारीकेँ पठा देब।
#
# প্রথমত স্যার আমরা জলই পেয়েছি অনেক ঝামেলার পর।
#
# सबसँ पहिने सर, हमरा सभ केँ बहुत परेशानीक बाद पानि भेटल।
#
# তার জন্য আমাদের নিয়মিত এই অফিসে আসতে হত।
#
# एकर लेल हमरा सभ केँ नियमित रूप सँ एहि कार्यालय मे आबि जयबाक जरूरत छलै।
#
# এমনকি সঠিক জল সরবারাহের দাবিতে এই অফিসের সামনে আমাদের একবার প্রতিবাদ জানাতে হয়েছে।
#
# हमरा सभकेँ एक बेर एहि कार्यालयक सामने उचित जल आपूर्तिक माँग करैत विरोध प्रदर्शन सेहो करय पड़लनि।
#
# অনেক ঝামেলার পরে আমরা তা পেয়েছি, কিন্তু এখন যে নালীর মধ্যে দিয়ে জলটা আসছে সেটা খুব নোংরা।
#
# बड्ड परेशानीक बाद हमरा सभकेँ ई भेटलनि, मुदा आब जाहि नालासँ पानि बहैत अछि से बड्ड गन्दा अछि।
#
# এটা কতটা নোংরা সেটা আরেকটু বলতে পারবেন?
#
# की अहाँ एकरा आओर किछु कहि सकैत छी जे ई कतेक गन्दा अछि?
#
# এটা কি ঘোলাটে নাকি এর মধ্যে কোনও ময়লা থাকছে?
#
# की ई गन्दा अछि वा एहिमे कोनो मैल अछि?
#
# এটা ঘোলাটে জল, স্যার।
#
# ई गन्दा पानि अछि, श्रीमान।
#
# তার সাথে ময়লাও রয়েছে।
#
# ओकरा संग मैल सेहो अछि।
#
# অনেক গ্রামবাসীকে এই জল ব্যবহার করার ফলে ত্বকের সমস্যায় ভুগতে হয়েছে।
#
# बहुतो गामबासिया एहि जलक उपयोगक परिणामस्वरूप त्वचाक समस्यासँ पीड़ित भेल छथि।
#
# ওহ, এটা তো খুব গুরুতর ব্যাপার।
#
# ओह, ई बड्ड गम्भीर बात अछि।
#
# হ্যাঁ স্যার, এটা খুবই গুরুতর ব্যাপার।
#
# हँ, श्रीमान, ई बड्ड गम्भीर बात अछि।
#
# আমাদের পুকুর ও টিউব কলেও পরিষ্কার জল নেই।
#
# हमरा लग तालाब आ ट्यूब कॉलमे सेहो साफ पानि नहि अछि।
#
# সেখানকার জলে প্রচুর পরিমাণে আয়রন রয়েছে।
#
# ओतऽ के पानि मे लोहा के मात्रा बहुत बेसी छैक।
#
# কিন্তু আমাদের এখন এই পুকুর এবং টিউব কলের জল ব্যবহার করা ছাড়া আর কোনও উপায় নেই ।
#
# मुदा आब हमरा सभ लग एहि तालाब आ ट्यूब मिलक पानि के उपयोग करय के अलावा कोनो विकल्प नहि अछि।
#
# এর ফলে গুরুতর স্বাস্থ্য সমস্যা দেখা দিচ্ছে।
#
# एकर परिणामस्वरूप गम्भीर स्वास्थ्य समस्या उत्पन्न भऽ रहल अछि।
#
# সরবরাহ করা জল পান করার পরে কেউ অসুস্থ হয়ে পড়েছে?
#
# आपूर्ति कयल गेल पानि पीलाक बाद की ककरो बीमारी भऽ गेल अछि?
#
# না স্যার, এখনও পর্যন্ত নয় কারণ আমারা এটা তক্ষুণি ব্যবহার করা একেবারে বন্ধ করে দিয়েছি।
#
# नहि सर, एखन धरि नहि, किएक तँ हम सभ एखनहि एकर उपयोग करब बन्द कऽ देने छी।
#
# বহু গ্রামবাসীর ত্বকের সমস্যা হতে দেখে, আমরা এটা ব্যবহার করা বন্ধ করে দিয়েছি।
#
# बहुतो गामवालोकनिक त्वचा सम्बन्धी समस्या देखलाक बाद हमसभ एकर उपयोग बन्द कऽ देलनि।
#
# নাহলে এর কারণে সহজেই আমাদের পেট ব্যথা আর পেট খারাপের মতন অসুখ দেখা দিত।
#
# नहि तऽ हमसभकेँ पेटमे दर्द आ पेट खराब सन बीमारी आसानीसँ भऽ जायत।
#
# আমি এক্ষুনি আপনার অভিযোগ কর্মকর্তার কাছে পাঠিয়ে দিচ্ছি।
#
# हम एखनहि अहाँक शिकायत अधिकारीकेँ पठा रहल छी।
#
# তিনি তারপরে কাউকে পরিস্থিতি পরিদর্শন করতে পাঠাবেন।
#
# तखन ओ परिस्थितिक निरीक्षण करबाक लेल ककरो पठबैत छथि।
#
# আপনি এখন বাড়ি যেতে পারেন।
#
# आब अहाँ घर जा सकैत छी।
#
# আমি বাকিটা করে দিচ্ছি।
#
# हम बाकी काज कऽ रहल छी।
#
# কী গো, আজ তোমাকে আমাদের নির্দিষ্ট ঠেকে দেখতে পেলাম না তো?
#
# की बात अछि, आइ हमरा सभ लग अहाँ सभ केँ नहि देखलहुँ?
#
# কোথায় ছিলে আজ?
#
# आइ अहाँ कतऽ छलहुँ?
#
# দেখে মনে হচ্ছে কোথাও থেকে ফিরছ?
#
# एना लगैत अछि जे अहाँ कोनो जगहसँ घुरल छी?
#
# কোথায় গেছিলে?
#
# अहाँ कतऽ गेल छी?
#
# লম্বা গল্প, আমায় একটু সময় দাও।
#
# लम्बा कहानी, हमरा किछु समय दियौक।
#
# আমি জামা বদলে এটা পরে নিই।
#
# हम एकरा पहिरैत छी आ कपड़ा बदलैत छी।
#
# জামাকাপড়ের কথা উঠল যখন, তোমারগুলো এলোমেলো আর নোংরা লাগছে।
#
# जखन कपड़ाक बात अबैत अछि तँ अहाँक कपड़ा अव्यवस्थित आ गन्दा लगैत अछि।
#
# ঠিক এই জন্যেই গ্রামে ঢোকার আগে আমি এটা বদলে ফেলছি।
#
# ठीक एहि लेल हम गाम मे प्रवेश करय सँ पहिने एकरा बदलि रहल छी।
#
# এবং আমি আমাদের নির্দিষ্ট ঠেকে আর যেতে পারব না।
#
# आ हम अपन निर्धारित सीमा पर आगू नहि बढ़ि सकैत छी।
#
# প্রতি সপ্তাহে সিগারেট টানার সামর্থ্য নেই আর।
#
# आब हर सप्ताह सिगरेट नहि पी सकैत छी।
#
# আমি ধূমপান ছাড়ার চেষ্টা করছি।
#
# हम धूम्रपान छोड़बाक कोशिश कऽ रहल छी।
#
# বাহ, এটা অপ্রত্যাশিত ছিল।
#
# वाह, ई अप्रत्याशित छल।
#
# এবং তোমার আগের প্রশ্নের উত্তরে বলি-
#
# आ हम अहाँक पहिल प्रश्नक उत्तरमे कहैत छी -
#
# আমি সবে কাছের গ্রামটা থেকে ফিরেছি।
#
# हम एखनहि लगक गामसँ घुरलहुँ।
#
# এই কয়েকদিনের বৃষ্টিতে ব্যবহার করার মতো রাস্তাটা ভেসে গেছে সুতরাং আমাকে গাড়ি বদল করে করে লিফট চেয়ে আসতে হল।
#
# एहि किछु दिनक बरखामे उपयोग करबाक लेल सड़क बह गेल अछि तेँ हमरा कार बदलय पड़लै आ लिफ्टक माँग करय पड़लै।
#
# তুমি সেখানে যাচ্ছিলেই বা কেন?
#
# बस अहाँ ओतऽ जा रहल छलहुँ वा किएक?
#
# তুমি আমায় জিজ্ঞেস করতে পারতে তোমার কোনও কিছু নিয়ে সাহায্য লাগবে কি না।
#
# अहाँ हमरा सँ पूछि सकैत छी कि अहाँकेँ कोनो चीजक लेल सहायताक आवश्यकता अछि कि नहि।
#
# এখানে তোমার সাহায্য আশা করতে পারি না।
#
# हम एतऽ अहाँक सहायताक अपेक्षा नहि कऽ सकैत छी।
#
# আমি সেখানে প্রত্যেক সকালে ফুটবল খেলতে যাই।
#
# हम हर भोर ओतऽ फुटबॉल खेलय लेल जाइत छी।
#
# সেই গ্রামের উল্টো দিকে গোলপোস্ট আর নেট লাগানো একটা মাঠ রয়েছে।
#
# गामक विपरीत दिशामे गोलपोस्ट आ जालसँ सुसज्जित एकटा मैदान अछि।
#
# যেহেতু এলাকাটা জনগণের সম্পত্তি, যে কেউ আসতে পারে এবং খেলতে পারে।
#
# चूँकि ई क्षेत्र लोकसभक सम्पत्ति अछि, कोनो व्यक्ति आबि सकैत अछि आ खेल सकैत अछि।
#
# তাই তুমি আগে আগে যাও খেলার জন্য জায়গা ও সময় পেতে, তাই তো?
#
# एहिलेल अहाँ खेलबाक लेल जगह आ समय प्राप्त करबाक लेल पहिने जाउ, सही नै?
#
# একদম, আমায় অন্তত ৭ঃ৩০ টার মধ্যে পৌঁছতেই হয়।
#
# ठीक अछि, हमरा कम सँ कम 7:30 बजे पहुँचबाक अछि।
#
# যার মানে আমাকে ৫টার মধ্যে বাড়ি থেকে বেরিয়ে যেতে হবে।
#
# जकर मतलब अछि जे हमरा 5 बजे धरि घरसँ बाहर निकलैत अछि।
#
# ব্যাপারটা খুবই ক্লান্তিকর কিন্তু কী আর করা যাবে, তাই না?
#
# ई बड्ड थकाऊ अछि मुदा आओर की कयल जा सकैत अछि, सही नै?
#
# আক্ষরিক অর্থে, এই গ্রামে একটাও অব্যবহৃত খোলা জায়গা নেই।
#
# शाब्दिक रूपसँ एहि गाममे एकटा सेहो अप्रयुक्त खुजल जगह नहि अछि।
#
# হ্যাঁ, আমারও মনে হয় এটা সত্যি।
#
# हँ, हमरा सेहो लगैत अछि जे ई सत्य अछि।
#
# তুমি বড়দের জিজ্ঞেস করেছ তারা কোনও জায়গা পরিষ্কার করে দিতে পারবে কি না?
#
# अहाँ बुजुर्ग सभ सँ पूछू जे की ओ कोनो जगह साफ कऽ सकैत छथि?
#
# না, তাদের কি ঠেকা পড়েছে করার?
#
# नहि, की हुनका सभकेँ रोकल जा सकैत अछि?
#
# তারা তাদের রাজনৈতিক এবং ধর্মীয় মতাদর্শ নিয়ে খুব বেশি জড়িয়ে আছে।
#
# ओ सब अपन राजनीतिक आ धार्मिक विचारधारामे बड्ड तल्लीन छथि।
#
# এমনকি আমার নিজের পরিবার চায় আমি স্কুলে যাওয়া বন্ধ করে রোজগার করতে শুরু করি।
#
# हमर अपन परिवार सेहो चाहैत अछि जे हम स्कूल जयब बन्द करी आ कमाई शुरू करी।
#
# তোমার মনে হয় তারা আমায় ফুটবল খেলার জন্য উৎসাহিত করবে?
#
# अहाँक विचार अछि जे ओ सभ हमरा फुटबॉल खेलबाक लेल प्रोत्साहित करत?
#
# বুঝতে পারি, খুবই দুঃখের এটা।
#
# हम बुझैत छी जे ई बड्ड दुखक बात अछि।
#
# আমাদের এখানে আসলে খেলার মতন ঠিকঠাক কোন ব্যবস্থাই নেই।
#
# हमरा सभ लग एतऽ खेलबाक लेल वास्तवमे नीक व्यवस्था नहि अछि।
#
# আমি কয়েকটা বুট কেনার জন্য আমার হাত খরচ বাঁচাচ্ছি।
#
# हम किछु बूट किनबाक लेल अपन हाथक लागत बचा रहल छी।
#
# তারপর আমি চেষ্টা-চরিত্র করব।
#
# तखन हम चरित्रक प्रयास करब।
#
# দেখা যাক কী হয়।
#
# आइ सभ देखू जे की होइत अछि।
#
# এই বছরের রেসলম্যানিয়া দেখেছ?
#
# की अहाँ एहि वर्षक रेसलमेनिया देखलहुँ अछि?
#
# কেমন একটা অন্যরকম লাগলো, তবে রোডসের প্রত্যাবর্তনের সঙ্গে এটা অবশ্যই একরকম উপভোগ্য ছিল।
#
# ई कतेक अलग लगैत छल, मुदा रोड्स के वापसी के संग ई निश्चित रूप सँ एक तरह सँ मजेदार छल।
#
# আমি সাধারণত কুস্তি বেশি একটা দেখি না, তবে এই বছর রেসলম্যানিয়ার জন্য উন্মুখ ছিলাম।
#
# हम सामान्यतः बेसी कुश्ती नहि देखैत छी, मुदा हम एहि साल रेसलमेनियाक प्रतीक्षा कऽ रहल छलहुँ।
#
# যদিও আমি দেখতে পাইনি, পরে শুধু হাইলাইটস দেখলাম।
#
# यद्यपि हम नहि देखलहुँ, बादमे मात्र मुख्य आकर्षण देखलहुँ।
#
# আমি জানতামই না কোথায় হচ্ছে।
#
# हमरा पता नहि छल जे ई कतऽ भऽ रहल अछि।
#
# আমি ভেবেছিলাম ইউটিউবে লাইভ চলবে।
#
# हम सोचलहुँ जे ई यूट्यूब पर लाइव चलत।
#
# কিন্তু তারপর দেখলাম সোনি টেন ১-এ।
#
# मुदा फेर हम सोनी टेन 1 पर देखलहुँ।
#
# ডবলু.ডবলু.ই চ্যানেলেও লাইভ হচ্ছিল।
#
# डब्ल्यू. डब्ल्यू. ई. सेहो चैनल पर लाइव भऽ रहल छल।
#
# ওহ, আমি জানতাম না যে এটা সোনি চ্যানেলে হয়।
#
# ओह, हमरा पता नहि छल जे ई सोनी चैनल पर होइत अछि।
#
# ওটা আসলে ২ দিনের জন্য হাইলাইট ছিল আর গোটা দিন ধরে চলেছে।
#
# ई वास्तवमे 2 दिन धरि मुख्य आकर्षण छल आ पूरा दिन धरि चलैत रहल।
#
# সোনি টেন ৩-এ হিন্দিতেও দেখতে পারো।
#
# सोनी टेन 3 पर हिन्दीमे सेहो देखल जा सकैत अछि।
#
# মিস করলাম তাহলে।
#
# तखन हमरा याद आबि गेल।
#
# পরেরটা দেখার চেষ্টা করবো, যখন হবে।
#
# हम अगिला पर एक नजर मारबाक कोशिश करब, जखन ई होयत।
#
# আমি সব সময় চেষ্টা করেছি পুরো লাইভ ইভেন্টটা দেখার কিন্তু এখানকার বেশীরভাগ চ্যানেলেই দেখায় না।
#
# हम हमेशा पूरा लाइव इवेंट देखबाक कोशिश कयलहुँ मुदा एतऽ बेसी चैनल पर नहि देखाइत छी।
#
# হ্যাঁ, তবে আরেকটা লাইভ ইভেন্ট দেখার জন্য তোমায় পরের রেসলম্যানিয়ার জন্য অপেক্ষা করতে হবে না।
#
# हँ, मुदा अहाँकेँ दोसर लाइव कार्यक्रम देखबाक लेल अगिला रेसलमेनियाक प्रतीक्षा करबाक आवश्यकता नहि अछि।
#
# আমেরিকাতে রেসলম্যানিয়া ব্যাকল্যাশ ২০২২ হতে চলেছে ৮ই মে সন্ধ্যে ৮টা নাগাদ।
#
# अमेरिकामे रेसलमेनिया बैकलैश 2022 8 मईकेँ राति 8 बजे धरि अयबाक अछि।
#
# তো সেটা ভারতে হবে ৯ই মে এবং ইভেন্ট সকাল ৫ঃ৩০এ শুরু হবে।
#
# तेँ ई 9 मईकेँ भारतमे होयत आ कार्यक्रम भोर 5:30 बजे शुरू होयत।
#
# আশা করছি এটা যেন দেখতে পারি।
#
# हमरा आशा अछि जे हम एकरा देखि सकैत छी।
#
# যদিও এটা চাপের হবে, ৯ই মে সোমবার।
#
# यद्यपि ई तनावपूर्ण होयत, सोम दिन 9 मई।
#
# তবে এটা অনেক লম্বা হবে, তাই তুমি তাও হয়তো শো-এর কয়েক ঘণ্টা দেখতে পারবে।
#
# मुदा ई बहुत लम्बा रहत, तेँ अहाँ शो के किछु घंटा सेहो देखि सकय छी।
#
# এই ব্যাকল্যাশের মূল ইভেন্টগুলো কি কি?
#
# एहि बैकलैशमे मुख्य घटना की की अछि?
#
# এই ইভেন্টে এ.জে স্টাইলস এজের বিরুদ্ধে এবং শেঠ রোলিন্স কোডি রোডসের বিরুদ্ধে লড়বে।
#
# एहि आयोजनमे एजे स्टाइल्स एजक विरुद्ध खेलतै जखन कि सेठ रॉलिंस कोडी रोड्सक विरुद्ध खेलतै।
#
# এই বছর রোডসের প্রত্যাবর্তনের পরে এটা একটা বড় ব্যাপার হতে চলেছে, ভক্তরা উত্তেজিত।
#
# एहि साल रोड्सक वापसीक बाद ई एकटा पैघ बात होयत, प्रशंसकसभ उत्साहित छथि।
#
# কোন উত্তেজনাপূর্ণ ট্যাগ ম্যাচ হবে কি?
#
# की कोनो रोमांचक टैग मैच होयत?
#
# আসলে হ্যাঁ, ইভেন্টে একটা ছয় জনের দলীয় ট্যাগ ম্যাচ হতে চলেছে।
#
# वास्तवमे हँ, एहि आयोजनमे छओ गोटाक टीम टैग मैच होयत।
#
# রোমান রেইনস ও ইউসোস ড্রু ম্যাকইনটায়ার ও আরকে-ব্রোর বিপক্ষে খেলবে।
#
# रोमन रेंस आ उसोस ड्रू मैकइंटायर आ आर. के.-ब्रो के खिलाफ खेलतै।
#
# ওইসব লোকেরা অনেক খেতাব জিতেছে।
#
# ओ सभ एहन लोक छथि जे बहुत रास खिताब जीतल छथि।
#
# এই রোমান রেইনস ডবলু.ডবলু.ই ইউনিভার্সালের চ্যাম্পিয়ন না?
#
# की ई रोमन रेंस डब्ल्यू. डब्ल्यू. ई. यूनिवर्सलक चैंपियन नहि अछि?
#
# হ্যাঁ আর ইউসোস হল স্ম্যাকডাউন ট্যাগ দলের চ্যাম্পিয়ন এবং আরকে-ব্রো হল র ট্যাগ দলের চ্যাম্পিয়ন।
#
# हँ आ उसोस स्मैकडाउन टैग टीम चैंपियन अछि आ आर. के.-ब्रो रॉ टैग टीम चैंपियन अछि।
#
# যদিও এটা টাইটেল ম্যাচ নয়, তাও ভক্তরা উত্তেজিত।
#
# यद्यपि ई कोनो खिताबी मैच नहि अछि, मुदा प्रशंसकसभ सेहो उत्साहित छथि।
#
# দুই পক্ষই ভক্তদের প্রিয় এবং রেণ্ডি অর্টন বনাম রেইনস এমন একটা ব্যাপার যার জন্য ভক্তরা উন্মুখ হয়ে রয়েছে।
#
# दुनू पक्ष प्रशंसकलोकनिक प्रिय अछि आ रैंडी ऑर्टन बनाम रेन्स एकटा एहन चीज अछि जकर लेल प्रशंसकसभ उत्सुक छथि।
#
# হ্যাঁ, তাই চেষ্টা করো আর দেখো যদি সম্ভব হয়, তবে, সময়টার জন্য কিছুটা চাপেরই হবে ।
#
# हँ, एहिलेल प्रयास करू आ देखू जे जँ सम्भव हो तँ ई समय लेल किछु तनावपूर्ण रहत।
#
# এই যে ডিম্পি, কেমন আছ তুমি?
#
# एतऽ डिंपी, अहाँ के तरह छी?
#
# আমাদের শেষবার কথা বলার পর বেশ কিছুদিন পেরিয়ে গেছে।
#
# किछु समय भऽ गेल अछि जखन हम अन्तिम बेर बात कयलहुँ।
#
# তোমার ওদিকে সব ঠিক আছে?
#
# की अहाँ ओतऽ नीक छी?
#
# আরে দেবাঙ্গ! আমি ভাল আছি।
#
# हे देवांग! हम नीक छी।
#
# হ্যাঁ, বেশ কিছুদিন হয়ে গেল।
#
# हँ, किछु समय भऽ गेल अछि।
#
# আমার এদিকে সব ভালই আছে, শুধু আমার খুড়তুতো ভাইটি ছাড়া।
#
# हमर चचेरा भाईकेँ छोड़ि एहि ठाम सब किछु ठीक अछि।
#
# ওহ! কি হয়েছে ওর?
#
# ओह! ओकरा की भऽ गेल अछि?
#
# আমার কিছুই শুনিনি কারোর কাছ থেকে।
#
# हम ककरो सँ किछु नहि सुनने छी।
#
# সে এখন ভাল আছে?
#
# की ओ आब ठीक छथि?
#
# গত সপ্তাহে তার একটা দুর্ঘটনা হয়।
#
# अगिला सप्ताह हुनका एकटा दुर्घटना भेल छल।
#
# ভগবানের কৃপায় এখন ভাল হয়ে উঠছে।
#
# भगवानक कृपासँ आब ठीक भऽ रहल अछि।
#
# ভাগ্যিস স্বাস্থ্য বীমা থেকে খরচটা মেটানো গেছে।
#
# सौभाग्यसँ स्वास्थ्य बीमा द्वारा खर्चक भुगतान कयल गेल अछि।
#
# শুনে ভাল লাগল যে ও সুস্থ হয়ে উঠছে।
#
# सुननेमे नीक लागि रहल अछि जे ओ ठीक भऽ रहल छथि।
#
# কীসের স্বাস্থ্য বীমা ছিল?
#
# कोन लग स्वास्थ्य बीमा छल?
#
# আমিও ভাবছি একটা স্বাস্থ্য বীমা নেব।
#
# हम सेहो स्वास्थ्य बीमा लेबाक विचार कऽ रहल छी।
#
# ওর স্বাস্থ্য বীমাটা ছিল স্টার হেলথ ইন্সিওরেন্সের।
#
# हुनकर स्वास्थ्य बीमा स्टार हेल्थ इंश्योरेंसक छल।
#
# ও একটা সরকারি পারিবারিক বীমা কিনেছিল।
#
# ओ सरकारी पारिवारिक बीमा कीनने छलीह।
#
# এটা পরিবারের ৫জন সদস্য অবধি কভার করে।
#
# ई परिवारक 5 सदस्य धरिकेँ कवर करैत अछि।
#
# কত প্রিমিয়াম দিতে হয়?
#
# कतेक प्रीमियम चुकयबाक अछि?
#
# এটা কি প্রতি মাসে রিনিউ করতে হয়?
#
# की एकरा हर महीना नवीनीकरण करय पड़तैक?
#
# এটা আমরা কিভাবে কিনব?
#
# हम एकरा कोना कीनब?
#
# এটা কি হাসপাতালে নগদ ছাড়া অ্যাডমিশনের সুবিধা দেয়?
#
# की ई अस्पतालमे बिना रोकटोक प्रवेशक सुविधा दैत अछि?
#
# তুমি যে প্ল্যানটা বেছে নেবে তার উপর ভিত্তি করে প্রিমিয়াম পরিবর্তিত হয়।
#
# प्रीमियम एहि बात पर निर्भर करैत अछि जे अहाँ कोन योजना चुनैत छी।
#
# অনেকগুলো প্ল্যান থেকে তুমি বেছে নিতে পার।
#
# अहाँ बहुत रास योजनामे सँ चुन सकैत छी।
#
# বিস্তারিত ব্যাখ্যা অনলাইনে পাওয়া যাবে।
#
# विस्तृत विवरण ऑनलाइन उपलब्ध अछि।
#
# তুমি মাসিক, ত্রৈমাসিক, ছয় মাসিক বা বার্ষিক হারে প্রিমিয়াম দিতে পার।
#
# अहाँ मासिक, त्रैमासिक, छओ मासिक अथवा वार्षिक दर पर प्रीमियम भS सकैत छी।
#
# হ্যাঁ, এই বীমাটা তাদের নেটওয়ার্ক হাসপাতালের মাধ্যমে হাসপাতালে নগদছাড়া অ্যাডমিশনের সুবিধা দেয়।
#
# हँ, बीमा हुनका अपन नेटवर्क अस्पतालक माध्यमसँ अस्पतालमे नकद-मुक्त प्रवेशक सुविधा दैत अछि।
#
# সারা ভারতে তাদের নেটওয়ার্কের অধীনে ৫০০ টারও বেশি হাসপাতাল আছে।
#
# पूरा भारतमे हुनक नेटवर्कक अन्तर्गत 500सँ बेसी अस्पताल अछि।
#
# এটা তো চমৎকার ব্যাপার!
#
# ई एकटा अद्भुत बात अछि!
#
# নগদহীন অ্যাডমিশনের সুবিধা হাসপাতালে ভর্তির সময়কার চাপ কমিয়ে দেয়।
#
# बिना नगद प्रवेशक सुविधा अस्पतालमे भर्ती होयबाक समयकेँ कम करैत अछि।
#
# আমাদের কাছে সব সময় নগদ থাকে না।
#
# हमरा सभ लग हर समय नगद नहि रहैत अछि।
#
# সবচেয়ে বড় কথা হল, আমরা জানি না কখন আর কীভাবে দুর্ভাগ্য আমাদের দরজায় কড়া নাড়বে।
#
# सबसँ महत्वपूर्ण बात ई अछि जे हमसभ नहि जनैत छी जे कखन आ कोना दुर्भाग्य हमरा सभक दरवाजा खटखटाबै।
#
# নথিভুক্তি করার সময় কি আমাদের কোনও মেডিকেল সার্টিফিকেট দিতে হবে?
#
# की पंजीकरण करैत काल हमरा सभकेँ कोनो चिकित्सा प्रमाणपत्र प्रस्तुत करबाक आवश्यकता अछि?
#
# আবেদনকারীরা, যাদের বয়স ৪০-এর বেশি নয় তাদের কোনও মেডিকেল সার্টিফিকেটের প্রয়োজন নেই।
#
# आवेदक, जे 40 सालसँ बेसी उम्रक नहि छथि, हुनका कोनो चिकित्सा प्रमाणपत्रक आवश्यकता नहि अछि।
#
# তোমার যদি আগে কোনও অসুখ থেকে থাকে তাহলে সেই সম্পর্কে তোমায় ফর্মে লিখতে হবে।
#
# अगर अहाँ के पहिने कोनो बीमारी छै तऽ फॉर्म मे लिखू।
#
# তালিকাভুক্ত হওয়ার প্রক্রিয়াটা সহজ।
#
# सूचीबद्ध करबाक प्रक्रिया सरल अछि।
#
# আমি কি এই বীমাটা অনলাইনে কিনতে পারি?
#
# की हम ई बीमा ऑनलाइन कीन सकैत छी?
#
# পলিসির কপিটা আমি কখন হাতে পাওয়ার আশা করতে পারি?
#
# हम पॉलिसीक प्रति कखन प्राप्त करबाक आशा कऽ सकैत छी?
#
# ওরা কি এটা পোস্টে পাঠায়?
#
# की ओ सभ एकरा पोस्ट पर पठा दैत छथि?
#
# হ্যাঁ, তুমি এটা অনলাইনে কিনতে পার।
#
# हँ, अहाँ एकरा ऑनलाइन कीन सकैत छी।
#
# অনলাইনে টাকা দেওয়ার পরে, ওরা পলিসিটার সফট কপি তোমার মেলে পাঠাবে।
#
# ऑनलाइन भुगतान कयलाक बाद ओ अहाँ केँ पॉलिसीक सॉफ्ट कॉपी मेल कऽ देत।
#
# এর একটা হার্ড কপি ডাকের মাধ্যমে তোমার কাছে পৌঁছে যাবে।
#
# एकर एकटा हार्डकॉपी डाक द्वारा अहाँ तक पहुँचाओल जायत।
#
# বিস্তারিত জানার জন্য অবশ্যই তাদের ওয়েবসাইটটা দেখ।
#
# विवरणक लेल निश्चित रूपसँ हुनक वेबसाइट देखू।
#
# আমি তোমাকে লিঙ্কটা পাঠাচ্ছি।
#
# हम अहाँ केँ लिंक पठा रहल छी।
#
# গোয়া, বাবা!!!
#
# गोवा, पिता!!!
#
# আমার তো বিশ্বাসই হচ্ছে না যে শেষ পর্যন্ত আমরা যাচ্ছি।
#
# हमरा विश्वास नहि होइत अछि जे हम अन्तमे जा रहल छी।
#
# এটা বোধহয় আমাদের সাত নম্বর বারের পরিকল্পনা।
#
# ई संभवतः हमर सभक सातम बेरक योजना अछि।
#
# এ তো পুরো দিল চাহতা হ্যায়-র মতো লাগছে।
#
# ई तो पूरा दिल चाहता है जकाँ लगैत अछि।
#
# আর এটা শেষমেশ হচ্ছে।
#
# आ ई अन्तमे होइत अछि।
#
# শুধু যদি এটা কনভার্টিব্‌ল হত আর তা হত লাল রঙের!
#
# यदि ई परिवर्तनीय छल आ ई लाल रङ्गक छल!
#
# তাই না?
#
# की ई नहि अछि?
#
# একদম দারুণ লাগছে।
#
# ई बड्ड बढ़िया लगैत अछि।
#
# তাহলে, আমাদের যাত্রার একটা পরিকল্পনা আছে তো?
#
# तऽ, की हमरा सभ लग यात्राक योजना अछि?
#
# নবীশ ভেবো না, তবে এটাই না আমার প্রথম রোড ট্রিপ।
#
# विश्वास नहि करू नबीश, मुदा ई हमर पहिल सड़क यात्रा नहि अछि।
#
# গতকাল রাতে আমি যে গানের সেরা প্লেলিস্ট বানিয়েছি সেটা শুনবো আমরা।
#
# हम सभ ओहि गीतक सर्वश्रेष्ठ प्लेलिस्ट सुनब जे हम काल राति बनेने छलहुँ।
#
# পালা করে গাড়ি চালাবো।
#
# हम बारी-बारीसँ गाड़ी चलबैत छी।
#
# আর জায়গায় জায়গায় চমৎকার সব ছবির জন্য দাঁড়াবো।
#
# आ सभ ठाम अद्भुत चित्रक लेल ठाढ़ भऽ जाउ।
#
# কেননা যাওয়ার পথের দৃশ্যগুলো দুর্দান্ত।
#
# किएक तँ बाटमे जे दृश्य देखल जा सकैत अछि से अद्भुत अछि।
#
# বলিউডের সবগুলো রোড ট্রিপের গান আশা করি তোমার কাছে আছে।
#
# आशा अछि जे अहाँ लग बॉलीवुडक सभ रोड ट्रिप गीत अछि।
#
# জেডএনএমডি আর দিল চাহতা হ্যায়-এর গানগুলো ছাড়া কোনও রোড ট্রিপ হতেই পারে না।
#
# जेड. एन. एम. डी. आ दिल चाहता है केर गीतक बिना कोनो रोड ट्रिप नहि भऽ सकैत अछि।
#
# একদম!
#
# बिलकुल!
#
# বলিউড আমাদের বিগড়ে দিয়েছে বলে মনে হয় আমার।
#
# हमर विचार अछि जे बॉलीवुड हमरा सभकेँ गड़बड़ कऽ देलक अछि।
#
# সব অভিজ্ঞতাকেই আমরা বলিউডের সঙ্গে তুলনা করি।
#
# हम सभ एहि अनुभवक तुलना बॉलीवुडक सङ्ग करैत छी।
#
# কিন্তু, তা কিছু ভালো মাপকাঠিও তৈরি করে দিয়েছে।
#
# मुदा, ई किछु नीक मानक सेहो स्थापित कयलक अछि।
#
# এই যে, এটা চালানো যাক।
#
# एतऽ, आओ एकरा चलाउ।
#
# আমি সহমত! আমার পুরো জীবনই বলিউডকে দিয়ে ঘেরা।
#
# हम सहमत छी! हमर पूरा जीवन बॉलीवुडसँ घेरायल अछि।
#
# তাহলে, কতক্ষণের পথ?
#
# तँ, मार्ग कतेक लम्बा अछि?
#
# যাওযার পথে কি আমরা ছবি তোলা ছাড়া আর কিছু করতে পারি?
#
# की हम सड़क पर जा कऽ फोटो खींचने के अलावा किछु कऽ सकैत छी?
#
# দাঁড়াও! আমার এক্ষুণি মনে পড়লো, এটা তোমার প্রথম রোড ট্রিপ বলছিলে না?
#
# रुकि जाउ! हमरा एखनहि याद आयल जे ई अहाँक पहिल सड़क यात्रा नहि छल?
#
# সত্যি?
#
# की ई सत्य अछि?
#
# তাই যদি হয়, আমাদের তো এটাকে স্মরণীয় করে তুলতে হবে।
#
# तेँ जँ अछि तँ हमरा सभकेँ एकरा स्मरणीय बनेबाक आवश्यकता अछि।
#
# করতেই হবে! আমি চাই এই অভিজ্ঞতাটা একদম আলাদাই হোক।
#
# करबाक चाही! हम चाहैत छी जे अनुभव बिलकुल अलग हो।
#
# আবার কবে এটা করতে পারবো জানি না।
#
# हमरा पता नहि कखन हम एकरा फेर सँ कऽ सकैत छी।
#
# ট্রেন আর প্লেনেই আমি বেশি অভ্যস্ত।
#
# हमरा ट्रेन आ विमानक बेसी आदत छैक।
#
# সেগুলো একটু বেশি সুবিধাজনক, না?
#
# ओ सभ किछु बेसी सुविधाजनक अछि, नै?
#
# বিশেষ করে ছোট ট্রিপ হলে।
#
# विशेष रूपसँ यदि छोट यात्रा अछि।
#
# আমার কাছে রোড ট্রিপ অনেক বেশি সুবিধাজনক।
#
# सड़क यात्रा हमरा लेल बहुत बेसी सुविधाजनक अछि।
#
# আর এগুলো আদতে একটা ছুটির মেজাজ নিয়ে আসে।
#
# आ ई सब वास्तवमे छुट्टीक मनोदशा अनैत अछि।
#
# যাতে তুমি বেশি করে রিল্যাক্স করতে পারো।
#
# ताकि अहाँ बेसी आराम कऽ सकी।
#
# আর প্লেনে.. হুশ.. আর তুমি পৌঁছে গেলে!
#
# आ विमानमे... हुश... आ अहाँ आबि गेल छी!
#
# ট্রেন তা-ও ভালো।
#
# ट्रेन सेहो नीक अछि।
#
# সেটা তো আছেই, কিন্তু রোড ট্রিপে ছুটির অর্ধেকটাই রাস্তায় কেটে যায়।
#
# ई ठीक अछि, मुदा सड़क यात्रा अपन आधा छुट्टी सड़क पर बितबैत अछि।
#
# কিন্তু, দু'টোরই নিজস্ব কিছু সুবিধা আছে বলে মনে হয়।
#
# मुदा, दुनूके अपन-अपन लाभ प्रतीत होइत अछि।
#
# গোয়া রোড ট্রিপ সম্বন্ধে আমার ধারণা বদলে দিতে পারে কিনা দেখা যাক।
#
# देखू जे गोवा सड़क यात्राक विषयमे हमर विचारकेँ बदलि सकैत अछि कि नहि।
#
# এটা তোমাকে বদলে দেবে।
#
# ई अहाँकेँ बदलि देत।
#
# কিন্তু তার আগে, আমাদের তেল ভরার জন্য একবার দাঁড়ানো প্রয়োজন।
#
# मुदा एहासँ पहिने, तेल भरबाक लेल हमरा सभकेँ एक बेर रुकबाक आवश्यकता अछि।
#
# মজা হতে চলেছে।
#
# ई मौज-मस्ती करय वाला अछि।
#
# তুমি যতক্ষণ তেল ভরাচ্ছো আমি বরং ততক্ষণ কয়েকটা ছবি তুলে নিই।
#
# जाबत धरि अहाँ तेल भरि रहल छी ताबत धरि हम किछु फोटो लैत छी।
#
# এই, তোমার ভাই এ পি ধিলোঁর কন্সার্ট উদ্যোক্তাদের চেনে শুনলাম।
#
# एह, हम अहाँक भाय ए. पी. ढिल्लनसँ सङ्गीत कार्यक्रमक उद्यमीसभकेँ चिन्हैत सुनलनि।
#
# বহুদিন ধরে আমি কয়েকটা পাসের খোঁজ করছি, কিন্তু এখনও পাইনি।
#
# हम बहुत दिनसँ किछु पास ताकैत रहलहुँ, मुदा एखन धरि नहि भेटल छी।
#
# আমাকে কি একটু সাহায্য করতে পারবে?
#
# की अहाँ हमरा किछु मदति कऽ सकैत छी?
#
# হ্যাঁ, উদ্যোক্তাদের দলেও ও আছে।
#
# हँ, उद्यमी समूहमे सेहो ओ छथि।
#
# আর এক্সট্রা টিকিট আছে কিনা জিজ্ঞাসা করবো ওকে।
#
# आ हम हुनका पूछब जे की हुनका लग अतिरिक्त टिकट अछि।
#
# ক'টা টিকিট লাগবে তোমার?
#
# अहाँकेँ कतेक टिकटक आवश्यकता पड़तैक?
#
# আমার আর আমার বন্ধুদের জন্য পাঁচটা টিকিট লাগবে।
#
# हमरा आ हमर मित्रसभकेँ पाँचटा टिकट चाही।
#
# প্ল্যান করার সময় একেকটা টিকিটের দাম ছিল প্রায় ১০ হাজার।
#
# जखन योजना बनाओल गेल छल तखन प्रत्येक टिकटक दाम लगभग १०, ००० छल।
#
# কিন্তু এখন ৩৫ থেকে ৪০ হাজারে বিক্রি হচ্ছে বলে শুনলাম।
#
# मुदा हम सुनने छी जे आब ई 35 सँ 40 हजारमे बिक रहल अछि।
#
# দামটাও নিশ্চিত করে বলতে পারবে?
#
# की अहाँ दामक पुष्टि सेहो कऽ सकैत छी?
#
# খরচটা আসলে উদ্যোক্তাদের হিসাবের বেশ খানিকটা বাইরে চলে গেছে।
#
# लागत वास्तवमे उद्यमीसभक हिसाबसँ बहुत बेसी छल।
#
# কিন্তু তুমি যেমন বলছো অতটাও দামী নয়।
#
# परंच ई ओना महग नहि अछि जेना अहाँ कहैत छी।
#
# কিছু দালাল ব্ল্যাকে বিক্রি করছে, তুমি হয়তো তাদের কাছ থেকেই শুনে থাকবে।
#
# किछु दलाल एकरा कारी रंगमे बेच रहल छथि, अहाँ हुनका सभसँ सुन सकैत छी।
#
# মাথাপিছু টিকিটের দাম ৮ হাজার।
#
# प्रति व्यक्ति टिकटक दाम 8 हजार अछि।
#
# কিন্তু এই মুহূর্তে ৫টা টিকিটের ব্যবস্থা করতে পারবো কিনা সন্দেহ আছে।
#
# मुदा एहि समय सन्देह अछि कि हम 5 टिकटक व्यवस्था कऽ सकैत छी कि नहि।
#
# দালালরাই যে দাম বাড়িয়ে দেয় সেটা তুমি একদম ঠিক বলেছো।
#
# अहाँ ठीक कहि रहल छी जे दलाल दाम बढ़ा दैत अछि।
#
# এগুলো উদ্যোক্তাদের কাছে পৌঁছয় না কিন্তু দামটাকে খুব প্রভাবিত করে।
#
# ई उद्यमीसभ तक नहि पहुँचैत अछि मुदा दामकेँ बहुत प्रभावित करैत अछि।
#
# ফ্যানেরা এতটাই পাগল যে তাও তারা এদের কাছ থেকেই কিনবে।
#
# प्रशंसक एते पागल भऽ जाइत छथि जे ओ सभ हुनका सभसँ कीनैत छथि।
#
# এই কারণে আমি পুরো প্ল্যানটাই বাতিল করে দিচ্ছিলাম, কিন্তু তখনই তোমার কথা মনে পড়লো।
#
# हम एहि कारणसँ पूरा योजनाकेँ रद्द कऽ रहल छलहुँ, मुदा तखनि हमरा अहाँक स्मरण भेल।
#
# ৫টা পাওয়া কঠিন হলে ‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍অন্তত ২টোর চেষ্টা করতে পারো কি?
#
# यदि 5 प्राप्त करब कठिन अछि तखन की अहाँ कम सँ कम 2 के प्रयास कऽ सकैत छी?
#
# ২টো টিকিটের ব্যবস্থা করাই যায়।
#
# 2 टिकटक व्यवस्था कयल जा सकैत अछि।
#
# আমার ভাইকে বলে খুব তাড়াতাড়িই টিকিটগুলো তোমার হাতে দিয়ে দেবো।
#
# हमर भाय केँ कहू जे हम जल्दी सँ जल्दी टिकट लऽ कऽ अहाँ केँ दऽ देब।
#
# টাকাটা তুমি ওকেই সরাসরি পাঠিয়ে দিতে পারো, সেটাই ভালো।
#
# अहाँ सीधा हुनका पैसा पठा सकैत छी, ई नीक अछि।
#
# ধন্যবাদ বন্ধু, প্রেমিকাকে কথা দিয়েছিলাম।
#
# धन्यवाद दोस्त, हम अपन प्रेमिका सँ वादा कयने छलहुँ।
#
# পরের কন্সার্ট অবধি আমাকে জ্বালাতন করতো।
#
# अगिला संगीत कार्यक्रम धरि हमरा चिढ़बैत रहैत छल।
#
# যাই হোক, গানের জন্য এসব কন্সার্টে কে যায় ভাই, আমার জন্য এটা শুধুই একটা নেশার মতো।
#
# बहरहाल, गीतक लेल एहि संगीत कार्यक्रममे कोन जाइत अछि भाई, ई हमरा लेल मात्र एकटा लत जकाँ अछि।
#
# কিন্তু এসব তো আর তোমাকে বলার মতো ওকে বলা যায় না, বন্ধু।
#
# मुदा आब ई बात हुनका अहाँ केँ कहबाक लेल नहि कहि सकैत छी, यार।
#
# বুঝতে পারছি।
#
# हम बुझैत छी।
#
# চিন্তা কোরো না, ২টো টিকিটের ব্যবস্থা ভালোভাবেই হয়ে যাবে।
#
# चिन्ता नहि करू, 2 टिकटक व्यवस्था नीक रहत।
#
# ভাইকে অলরেডি বলে দিয়েছি আর ও তোমার টিকিটগুলো বুকও করে দিয়েছে।
#
# हम अपन भायकेँ ऑलरेडी बता चुकल छी आ ओ अहाँक टिकट बुक कऽ लेने अछि।
#
# অতএব, নিশ্চিন্তে থাকতে পারো আর কালকে দেখা হলে নিয়ে নিও আমার কাছ থেকে।
#
# एहिलेल सुरक्षित रहू आ जँ अहाँ काल भेँट करब तँ हमरा सँ छीन लिअ।
#
# একদম ভাই, থ্যাঙ্ক ইউ।
#
# बस भाई, धन्यवाद।
#
# মোস্ট ওয়েলকাম, খুব তাড়াতাড়ি দেখা হচ্ছে।
#
# बहुत बहुत स्वागत अछि, बहुत जल्दी भेँट करू।
#
# নমস্কার, আপনি কি ট্রিনিটি এলিমেন্টারি স্কুলের আর্টসের শিক্ষক মিসেস রাধিকা?
#
# नमस्कार, की अहाँ ट्रिनिटी एलीमेंट्री स्कूलक कला शिक्षक श्रीमती राधिका छी?
#
# হ্যাঁ, আপনি কে?
#
# हँ, अहाँ कोन छी?
#
# আমার নাম জন বার্ণাড, আর আমি মিশেলের বাবা।
#
# हमर नाम जॉन बर्नार्ड अछि, आ हम मिशेलक पिता छी।
#
# আচ্ছা স্যার, বলুন আমি আপনাকে কিভাবে সাহায্য করতে পারি?
#
# ठीक अछि, श्रीमान, हमरा बताउ जे हम अहाँक कोना मदति कऽ सकैत छी?
#
# মিশেল গান শেখার প্রতি আগ্রহ প্রকাশ করেছে।
#
# मिशेल गायन सिखबाक लेल अपन रुचि व्यक्त कयने छथि।
#
# আমি একটি ধারা বেছে নেওয়া নিয়ে খুবই দ্বিধাগ্রস্ত।
#
# हम एकटा शैली चुनबाक लेल बड्ड हिचकिचा रहल छी।
#
# আপনি কি আমায় সাহায্য করতে পারবেন?
#
# की अहाँ हमर सहायता कऽ सकैत छी?
#
# শেখার জন্য সবচেয়ে সহজ ধারার গান কোনটা?
#
# सबसँ आसान शैलीक गीत कोन अछि जे सीखल जा सकैत अछि?
#
# নিশ্চয়ই।
#
# अवश्य।
#
# আমার মতে, ছোটদের শাস্ত্রীয় সঙ্গীত শেখা উচিত।
#
# हमर विचारमे छोट बच्चासभकेँ शास्त्रीय संगीत सीखबाक चाही।
#
# শিশুদের জন্য শাস্ত্রীয় সঙ্গীত শেখা কি উপকারী?
#
# की बच्चासभ लेल शास्त्रीय संगीत सीखब लाभदायक अछि?
#
# হ্যাঁ। এটা খুবই কঠিন কিন্তু শিশুদের জন্য শাস্ত্রীয় সঙ্গীতের বিশাল মানসিক উপকারিতা রয়েছে।
#
# हँ। ई बड्ड कठिन अछि मुदा बच्चासभ लेल शास्त्रीय संगीतक बहुत रास भावनात्मक लाभ अछि।
#
# গবেষণা অনুযায়ী লাইভ শাস্ত্রীয় সঙ্গীত শুনলে শিশুদের মধ্যে ইতিবাচক অনুভূতি জাগে।
#
# शोधक अनुसार सजीव शास्त्रीय संगीत सुनबासँ बच्चासभमे सकारात्मक भावना उत्पन्न होइत अछि।
#
# এটা তাদের শোনা আর একাগ্রতার ক্ষমতার উপরেও প্রভাব ফেলে।
#
# ई सुनबाक आ ध्यान केन्द्रित करबाक हुनक क्षमताकेँ सेहो प्रभावित करैत अछि।
#
# শাস্ত্রীয় সঙ্গীত শিশুদের বিকাশের জন্য উপকারী, তা ভালো।
#
# शास्त्रीय संगीत बच्चासभक विकासक लेल नीक अछि।
#
# শাস্ত্রীয় সঙ্গীতের আর কী কী উপকারিতা রয়েছে?
#
# शास्त्रीय संगीतक आओर की लाभ अछि?
#
# শাস্ত্রীয় সঙ্গীতে অনুশীলন ও অধ্যবসা অপরিহার্য।
#
# शास्त्रीय संगीतमे अभ्यास आ दृढ़ता आवश्यक अछि।
#
# এই প্রশিক্ষণ শিশুর জীবনকে নিয়মানুবর্তী করবে।
#
# ई प्रशिक्षण बच्चाक जीवनकेँ व्यवस्थित करत।
#
# এটা অবসাদ কমাতেও হিসেবে কাজ করে।
#
# ई अवसादकेँ कम करबा लेल सेहो काज करैत अछि।
#
# এটা শিশুদের মনকে শান্তও করে।
#
# ई बच्चासभक दिमागकेँ सेहो शान्त करैत अछि।
#
# হ্যাঁ, একজন শান্ত শিশু অনেক বেশি আনন্দময়।
#
# हँ, एकटा शान्त बच्चा बहुत बेसी प्रसन्न होइत अछि।
#
# যেহেতু শিশুরা শুধুমাত্র কান দেওয়ার চেয়ে মনোযোগ দিয়ে শুনতে শেখে,
#
# चूँकि बच्चा मात्र कान देबाक बदला ध्यानसँ सुननाइ सीखैत अछि,
#
# তাদের স্মৃতি কোষগুলো ধ্বনি, সুর, কণ্ঠস্বর, পদ্ধতি, পন্থা এবং আরও অনেক কিছু সংরক্ষণ করতে আরও বেশি কাজ করতে শুরু করে।
#
# हुनकर स्मृति कोशिका ध्वनि, स्वर, स्वर, पद्धति, दृष्टिकोण आ बहुत किछु संचित करबाक लेल बेसी काज करय लगैत अछि।
#
# ঠিক আছে, আমি মিশেলের জন্য এই এলাকাতে শাস্ত্রীয় সঙ্গীতের শিক্ষক খুঁজে দেখব।
#
# ठीक अछि, हम एहि क्षेत्रमे मिशेल लेल शास्त्रीय संगीतक शिक्षक ताकब।
#
# আমি বুঝলাম যে শাস্ত্রীয় সঙ্গীত ভারতের প্রাণ।
#
# हम बुझलनि जे शास्त्रीय संगीत भारतक प्राण अछि।
#
# দারুণ।
#
# बढ़िया अछि।
#
# অনুগ্রহ করে মাথায় রাখবেন যে, যদি সে শাস্ত্রীয় সঙ্গীত শিখতে আগ্রহী না হয়, তাহলে তাকে এটা শিখতে জোর করবেন না।
#
# कृपया ध्यान राखू जे जँ ओ शास्त्रीय संगीत सिखबाक इच्छुक नहि अछि तँ ओकरा एकरा सिखबाक लेल बाध्य नहि करू।
#
# আমাদের উচিত যোগ্যতার ওপর নির্ভর করে ওদের উৎসাহিত করা।
#
# हमरा सभकेँ योग्यताक आधार पर हुनका सभकेँ प्रोत्साहित करबाक चाही।
#
# অবশ্যই ম্যাডাম।
#
# बेशक, मैडम।
#
# আপনার সাহায্যের জন্য আপনাকে অনেক ধন্যবাদ।
#
# अहाँक सहायताक लेल बहुत बहुत धन्यवाद।
#
# আপনাকে ওয়েলকাম, আর দয়া করে মিশেলকে আমার শুভেচ্ছা জানাবেন।
#
# अहाँक स्वागत अछि, आ कृपया मिशेलकेँ हमर शुभ कामना।
#
# আচ্ছা, বাই!
#
# ठीक अछि, अलविदा!
#
# আগামীকাল তোমার ছুটি আছে?
#
# की अहाँकेँ अगिला दिन छुट्टी अछि?
#
# একটা কাজের দিনে আমার ছুটি থাকতে যাবে কেন?
#
# हमरा कोनो कार्य दिवस पर छुट्टी किएक भेट सकैत अछि?
#
# আসলে আগামীকাল একটা সমাবেশ হবে।
#
# वास्तवमे कल एकटा सभा होयत।
#
# আমাদের পাড়ার ছেলেমেয়েগুলোর ছুটি।
#
# हमर पड़ोसक बच्चासभ लेल छुट्टी अछि।
#
# আমি ভাবলাম তোমারও তাই।
#
# हम सोचलहुँ जे अहाँ सेहो एहन छी।
#
# আমার কোনও ছুটি নেই।
#
# हमरा लग कोनो छुट्टी नहि अछि।
#
# তাহলে আমার মনে হয় আরও ভালো হয় যদি তুমি আগামীকালের জন্য একটা ছুটি নিয়ে নাও।
#
# तऽ हमरा लगैत अछि जे नीक होयत यदि अहाँ अगिला दिन लेल छुट्टी लैत छी।
#
# এই সমাবেশটা কী এমন বড় ব্যাপার?
#
# ई सभा एते पैघ की अछि?
#
# অনেক সমাবেশই তো হচ্ছে সবসময়।
#
# हमेशा बहुत रास सभा होइत अछि।
#
# এইটা বিশাল হবে।
#
# ई बहुत पैघ होयत।
#
# কারণ সব বড় দলগুলো, ভারতীয় জনতা পার্টি, তৃণমূল কংগ্রেস এবং কমিউনিস্ট পার্টি এতে যোগদান করবে।
#
# किएक तँ सभ प्रमुख दल, भारतीय जनता पार्टी, तृणमूल कांग्रेस आ कम्युनिस्ट पार्टी एहिमे शामिल होयत।
#
# তাদের সবাই?
#
# ओ सभ?
#
# হ্যাঁ এবং তুমি সময়মতো বাড়ি পৌঁছতে পারবে কি না তা নিয়ে আমার যথেষ্ট সন্দেহ আছে।
#
# हँ आ हमरा बड्ड सन्देह अछि जे अहाँ समय पर घर पहुँचब कि नहि।
#
# যদি তুমি আগামীকাল অফিস যাও।
#
# जँ अहाँ कल कार्यालय जाउ।
#
# আমারও তাই সন্দেহ হচ্ছে।
#
# हमरा सेहो एहि पर सन्देह भऽ रहल अछि।
#
# কিন্তু আমি এই সম্পর্কে কিছুই জানিনা।
#
# मुदा हम एहि विषयमे किछु नहि जनैत छी।
#
# কেন করছে তারা এইসব?
#
# ओ सभ ई सभ किएक कऽ रहल छथि?
#
# তারা এইসব করছে কারণ সরকার ঘোষণাপত্রে যা যা বলেছিল তার সবটা তারা করেনি।
#
# ओ सभ ई एहि लेल कऽ रहल छथि जे ओ सभ एहन काज नै कयने छथि जे सरकार घोषणा पत्रमे कहि चुकल अछि।
#
# তাই কি?
#
# तँ की?
#
# তাহলে ভারতীয় জনতা পার্টি যখন ক্ষমতায় ছিল সেই সময়ে কী হয়েছিল?
#
# तखन भारतीय जनता पार्टी जखन सत्तामे छल तखन की भेल?
#
# তারাও তো যা কথা দিয়েছিল সেসব করেনি।
#
# ओ सभ सेहो ओ सभ नहि कयलनि जे ओ सभ वादा कयने छलाह।
#
# ঠিক, তবে কে ধার ধারে?
#
# ठीक अछि, मुदा ऋण पर कोन अछि?
#
# রাজনীতি তো সবসময়ই এরকম, তাই না?
#
# राजनीति हमेशा एहि तरहेँ होइत अछि, सही नै?
#
# হ্যাঁ, প্রচার ও অন্যান্য লাভের জন্য তারা একে অপরের বিরুদ্ধে প্রতিবাদ জানায়।
#
# हँ, ओ प्रचार आ अन्य लाभक लेल एक दोसराक विरोध करैत छथि।
#
# কিন্তু আসলে এইসব করে তারা কিচ্ছু পায়না,
#
# मुदा वास्तवमे ओ सभ एना कय किछु नहि प्राप्त करैत छथि।
#
# কেবল আমরা ছাড়া, যারা জ্যামজট এবং সব কিছুর জন্য ভুগতে থাকি।
#
# हमरा सभक अतिरिक्त, जे सभ अराजकता आ सब किछुक कारणेँ पीड़ित रहैत छथि।
#
# একদম, আশা করছি আগামীকাল এটা সন্ধ্যা পর্যন্ত চলবে না।
#
# ठीक अछि, आशा अछि जे ई अगिला दिन साँझ धरि नहि चलत।
#
# তুমি কি যাবে?
#
# की अहाँ जा रहल छी?
#
# আমাকে যেতেই হবে, অফিসে প্রচুর কাজ রয়েছে।
#
# हमरा जरूर जयबाक अछि, ऑफिसमे बहुत काज अछि।
#
# এইসবের জন্য আমি ছুটি নিতে পারব না।
#
# एहि कारणेँ हम छुट्टी नहि लऽ सकैत छी।
#
# তাহলে আগামীকাল গণ পরিবহণে যেও।
#
# तऽ कल सार्वजनिक परिवहन पर जाउ।
#
# আমরা তো জানিনা কী হতে চলেছে।
#
# हम सभ नहि जनैत छी जे की भS सकैत अछि।
#
# যদি কোনও মারপিট হয়?
#
# यदि कोनो मार-पीट भेल हो तखन की होयत?
#
# মনে আছে, এক বছর আগে ওরা তোমার সহকর্মীর বাইক পুড়িয়ে দিয়েছিল?
#
# याद अछि एक साल पहिने ओ सभ अहाँक सहकर्मीक बाइककेँ जला देलकनि?
#
# তুমি বেশী চিন্তা করছ।
#
# अहाँ बेसी चिन्तित छी।
#
# সেরকম কিচ্ছু ঘটবে না।
#
# एहन किछु नहि होयत।
#
# অ্যাই, তুমি ভূগোলে সবসময় কি করে সর্বোচ্চ নম্বর পাও বলো তো?
#
# अरे, अहाँ भूगोलमे सबसँ बेसी अंक कोना प्राप्त करैत छी?
#
# পড়াশোনা তো প্রায় করো না বললেই চলে।
#
# पढ़ाई नहि करबाक बात बेसीकाल एहि तरहेँ कयल जाइत अछि।
#
# আর এদিকে আমাকে দেখো!
#
# आ एतऽ हमरा देखू!
#
# হাই, আমি আমার ছোট একটা গুপ্ত কথা মেনে চলি।
#
# नमस्कार, हम अपन एकटा छोट-छोट रहस्यक पालन करैत छी।
#
# কাউকে বলি না...‍
#
# ककरो नहि बताउ...
#
# ইয়ার্কি না করে বলছি, ভূগোলের প্রতি প্রথম থেকেই আমার গভীর আগ্রহ।
#
# ई कहबाक आवश्यकता नहि अछि जे भूगोलमे हमर बड्ड रुचि शुरूसँ अछि।
#
# সত্যি কথা বলতে, বিষয়টা আমি সর্বক্ষণ পড়ি না।
#
# ईमानदारी सँ, हम सब समय विषय नहि पढ़ैत छी।
#
# ক্লাস চলাকালীন ম্যাম যখন আমাদের চ্যাপ্টারগুলো পড়ান তখন আসল দৃশ্যের সঙ্গে মিলিয়ে মনের মধ্যে একটা ছবি এঁকে নেওয়ার চেষ্টা করি আমি।
#
# हम अपन दिमाग मे एकटा तस्वीर खींचने के कोशिश करैत छी, जे वास्तविक दृश्य सँ मेल खाइत अछि, जखन कक्षा के दौरान मैम हमरा सभ केँ अध्याय पढ़बैत छथि।
#
# এর মাধ্যমে ধারণাগুলোও আমার কাছে পরিষ্কার হয়ে যায়।
#
# एहि तरहेँ विचार सेहो हमरा लेल स्पष्ट भऽ जाइत अछि।
#
# আসল দৃশ্যের সঙ্গে মেলানো বলতে কি বোঝাচ্ছো?
#
# अहाँक वास्तविक दृश्यसँ मेल खयबाक की मतलब अछि?
#
# এটা তো ভূগোল! এতে তো আছে বলতে শুধুই পাহাড়, নদী, সমুদ্র, জলবায়ু আর অপ্রয়োজনীয় সংখ্যা।
#
# ई भूगोल अछि! एहिमे मात्र पहाड़, नदी, समुद्र, जलवायु आ अनावश्यक संख्या अछि।
#
# এর মধ্যে তোমার পছন্দই বা কি হয়?
#
# एहिमे अहाँकेँ की पसिन्न पड़ैत अछि?
#
# সব একঘেয়ে বিষয়ের মধ্যে সবথেকে একঘেয়ে তো এটাই।
#
# ई सब सबसँ नीरस चीजसभमे सँ सबसँ नीरस अछि।
#
# যদি তুমি সেরকমভাবে ভাবো।
#
# जँ अहाँ एहि तरहेँ सोचय छी।
#
# তুমি তো জানো যে আমি খুব ঘুরে বেড়াই আর অনেক সিনেমা দেখি।
#
# अहाँ जनैत छी जे हम बड्ड घुमैत छी आ कतेक सिनेमा देखैत छी।
#
# যা কিছু আমরা পড়ি সবই আমাদের আশেপাশে আছে, আমাদের শুধু তাকিয়ে দেখতে হবে।
#
# जे किछु हम पढ़ैत छी से सभ हमरा सभ लग-पास अछि, हमरा सभ केँ बस देखू आ देखू।
#
# তাই, যা-ই পড়ি না কেন, আমার ঘুরে আসা কোনও জায়গা অথবা সিনেমায় দেখা ছবিগুলোর কথা মনে করে সেগুলোর সঙ্গে মেলানোর চেষ্টা করি আমি।
#
# तेँ, जे किछु हम पढ़ैत छी, हम ओकर मिलान करबाक प्रयास करैत छी, कोनो एहन स्थानक स्मरण करैत छी जकर हम दौरा कयने छी वा फिल्ममे देखलहुँ।
#
# এরকমভাবে, আমার ক্ষেত্রে এটা অনেকাংশেই চোখের সামনে ফুটে ওঠে, আর অনেক বেশি সময়ের জন্য মনেও রাখতে পারা যায়।
#
# एहि तरहेँ, ई हमरा लेल बहुत हद तक दृष्टिगोचर होइत अछि, आ बहुत दिन धरि स्मरणीय रहैत अछि।
#
# এরকম ভাবে পড়াশোনা করার কথা ভেবেছো কখনও?
#
# की अहाँ कहियो एहि तरहेँ अध्ययन करबाक विचार कयलहुँ अछि?
#
# তুমি হয়তো ঠিকই বলছো, কিছু কিছু সময় এই পদ্ধতিটা সত্যিই কার্যকর হয়।
#
# भऽ सकैत अछि जे अहाँ सही छी, कखनो काल ई विधि वास्तवमे उपयोगी होइत अछि।
#
# কিন্তু কি জানো তো, ভূগোলের মতো একটা বিষয়ের সঙ্গে আমার পক্ষে তা মেলানো খুবই কঠিন।
#
# मुदा की अहाँ जनैत छी, भूगोल सन कोनो वस्तुक सङ्ग एकर मिलान करब हमरा लेल बड्ड कठिन अछि।
#
# তুমি খুব ঘুরে বেড়াও বলে হয়তো এটা তোমাকে টানে; অপর দিকে, আমার ক্ষেত্রে এগুলো সবই কাল্পনিক তথ্য।
#
# भऽ सकैत अछि जे ई अहाँकेँ एहि तथ्यसँ आकर्षित करैत अछि जे अहाँ बहुत घुमैत छी; दोसर दिस हमर विषयमे ई सभ काल्पनिक तथ्य अछि।
#
# তাছাড়া, ভারতীয় ভূগোল আমাদের সিলেবাসের অংশ, আর তোমরা বোধহয় পৃথিবীর সবথেকে ভালো জায়গাগুলো সম্পর্কে পড়ো।
#
# एकर अतिरिक्त, भारतीय भूगोल हमर पाठ्यक्रमक हिस्सा अछि, आ अहाँ संभवतः दुनियाक सबसँ नीक स्थानसभ पर पढ़ब।
#
# আমাদের ক্ষেত্রে ব্যাপারটা আলাদা!
#
# हमरा सभक संग ई अलग बात अछि!
#
# একটু যে আলাদা সেটা বুঝতে পারছি, কিন্তু কিছু নির্দিষ্ট বিষয়ের ওপর কয়েকটা ভিডিও দেখলে সেখান থেকেও তুমি কিছুটা ধারণা পাবে।
#
# हम बुझैत छी जे ई किछु अलग अछि, मुदा किछु विषय पर किछु वीडियो देखलासँ अहाँकेँ ओहि सँ किछु विचार सेहो भेटत।
#
# আমি সেরকমভাবেই শুরু করেছিলাম, তার পরে বিকল্পের খোঁজ পেয়েছি।
#
# हम एहि तरहेँ शुरू कयलहुँ, तकर बाद विकल्पक खोज कयलहुँ।
#
# অনেকাংশেই এটা অডিও-ভিজ্যুয়াল।
#
# बहुत हद तक ई ऑडियो-विजुअल अछि।
#
# তুমি চাইলে এই ব্যাপারে আমি তোমায় সাহায্য করতে পারি।
#
# जँ अहाँ चाहैत छी तँ हम एहिमे अहाँक सहायता कऽ सकैत छी।
#
# হ্যাঁ, সেটা তো আমার ভালোই লাগবে।
#
# हँ, हमरा ई पसिन्न पड़त।
#
# তোমার কি মনে হয়, তোমার এতো ঘুরে বেড়ানো কি বিষয়টার প্রতি তোমার আগ্রহ তৈরি করেছে নাকি উল্টোটাও সম্ভব?
#
# की अहाँकेँ लगैत अछि जे एहि तरहेँ घुमैत रहबाक कारणेँ अहाँक रुचि बढ़ि गेल अछि वा एकर उल्टा भऽ सकैत अछि?
#
# মানে, বিভিন্ন জায়গা ঘুরে বেড়ানোর সময় আবহাওয়ার অবস্থা, জায়গা, গঠন আর বাকি যা কিছুর তথ্য সব কাজে লাগে?
#
# हमर मतलब अछि, मौसमक स्थिति, स्थान, संरचना आ बाकी सब जानकारी जखन अहाँ अलग-अलग जगह घुमैत छी तखन उपयोगी होयत अछि?
#
# বিশেষ করে ভারতবর্ষে, যেখানে দেখার মতো প্রায় কিছু নেই বললেই চলে!
#
# विशेष रूपसँ भारतमे, जतय देखबाक लेल लगभग किछु नहि अछि!
#
# ব্যাপারটা কিন্তু সেরকম নয়।
#
# मुदा बात एहन नहि अछि।
#
# ভারতবর্ষে দেখার মতো অনেক কিছু আছে, বেশির ভাগ গুরুত্বপূর্ণ জলাশয়, পাহাড় আর সমতলও তুমি ভারতেই পাবে।
#
# भारतमे देखबाक लेल बहुत किछु अछि, अधिकांश महत्वपूर्ण जल निकाय, पहाड़ आ मैदान अहाँ भारतमे पाबि सकैत छी।
#
# যেমন ধরো, বিভিন্ন রাজ্য থেকে দেখতে পাওয়া কাঞ্চনজঙ্ঘার মতো হিমালয়ের অন্যান্য পর্বতমালাগুলি অদ্বিতীয় এবং প্রতিটি পর্বতমালারই ভাগ করে নেওয়ার মতো নিজস্ব কিছু বৈশিষ্ট্য রয়েছে।
#
# जेना कि मानि लिअ, हिमालयक अन्य श्रृंखला, जेना कि कंचनजंगा, जे अलग-अलग राज्यसँ देखल जा सकैत अछि, अद्वितीय अछि आ प्रत्येक श्रृंखलाक अपन-अपन विशेषता अछि जे ओ साझा करैत अछि।
#
# জলের অংশও বিভিন্ন জায়গায় ভাগ হয়ে গিয়ে ব-দ্বীপ আর দ্বীপ তৈরি করেছে।
#
# जल निकाय सेहो अलग-अलग स्थान पर विभाजित भऽ गेल अछि जाहि सँ डेल्टा आ द्वीप बनल अछि।
#
# সেইসব স্থলভূমিরও নিজস্ব কিছু অনন্য বৈশিষ্ট্য রয়েছে।
#
# ओहि स्थलक अपन किछु अद्वितीय विशेषता सेहो अछि।
#
# তুমি বোধহয় ঠিকই বলছো! মিস লিয়া তাঁর ভারতীয় ভূগোলের ক্লাসে আমাদের জন্য কিভাবে মনোগ্রাহী এক বর্ণনা এঁকেছিলেন আমার মনে আছে।
#
# भऽ सकैत अछि जे अहाँ सही छी! हमरा याद अछि जे सुश्री ली अपन भारतीय भूगोल कक्षामे हमरा सभक लेल कतेक आकर्षक वर्णन केने छलीह।
#
# ব্যাপারটা হলো যে বিভিন্ন উপায় অবলম্বন করে কিভাবে বিষয়টাকে আরও আকর্ষক করে তুলতে পারো।
#
# बात ई अछि जे अहाँ एकरा बेसी रोचक बनेबाक लेल विभिन्न तरीकासँ कोना काज कऽ सकैत छी।
#
# অনেকদিনের জন্য বাড়ি ছেড়ে যেতে আমার ভালো লাগে না, কিন্তু তোমার মতো করে খোলা মনে চেয়ে দেখার চেষ্টা করবো।
#
# हमरा बेसी समय धरि घर छोड़ब पसिन्न नहि होइत अछि, मुदा हम अहाँक जकाँ खुला दिमाग रखबाक प्रयास करब।
#
# এই শো আর সিনেমাগুলো কাজে লাগতে পারে।
#
# ई शो आ सिनेमा काज कऽ सकैत अछि।
#
# কথা বলে ভালো লাগলো, ভাই! অনেক ধন্যবাদ!
#
# बड्ड नीक लागि रहल अछि भाई! बहुत बहुत धन्यवाद!
#
# ওয়েলকাম।
#
# स्वागत अछि।
#
# হ্যালো, আমি বিশ্ববিদ্যালয়ের হোস্টেল থেকে জেড স্কোয়ার মল যাওয়ার জন্য গাড়ি বুক করার ব্যাপারে কল করছি।
#
# नमस्कार, हम विश्वविद्यालयक छात्रावाससँ जेड स्क्वायर मॉल धरि गाड़ी बुक करबाक लेल फोन कऽ रहल छी।
#
# কত তাড়াতাড়ি পেতে পারি?
#
# हम कतेक जल्दी प्राप्त कऽ सकैत छी?
#
# আমি এক্ষুনি আমাদের একজন ড্রাইভারকে আপনার ঠিকানায় পাঠিয়ে দিতে পারি।
#
# हम एखनहि अपन चालकमेसँ एककेँ अहाँक पता पर पठा सकैत छी।
#
# আপনি কোথা থেকে তুললে ভালো হয়?
#
# अहाँ एकरा कतऽसँ उठबैत छी से नीक अछि?
#
# আমি মেইন ক্যম্পাসেই অপেক্ষা করব, যেটা প্রবেশদ্বারের খুব কাছে।
#
# हम मुख्य परिसरमे प्रतीक्षा करब, जे प्रवेश द्वारक बहुत करीब अछि।
#
# নিরাপত্তারক্ষী ঝামেলা না করেই আপনাকে ঢুকতে দেবে।
#
# सुरक्षा कर्मी अहाँकेँ बिना कोनो परेशानीक भीतर प्रवेश करबाक अनुमति देत।
#
# বেশ, ক্যাম্পাস চত্বরে গাড়ি ঢুকতে পারবে?
#
# ठीक अछि, की कार परिसरमे प्रवेश कऽ सकैत अछि?
#
# এর অনুমতি আছে?
#
# की एकर अनुमति अछि?
#
# আমরা একবার আরেকটা বিশ্ববিদ্যালয়ের ক্ষেত্রে ঝামেলায় পড়ে গেছিলাম, আমি শুধুমাত্র নিশ্চিত হওয়ার জন্য জিজ্ঞেস করছি।
#
# हम सभ एक बेर दोसर विश्वविद्यालयक मामलामे फँसि गेल छलहुँ, हम मात्र एकर पुष्टि करबाक लेल कहि रहल छी।
#
# যতক্ষণ পর্যন্ত তাদের আগে থাকতে জানানো থাকে ততক্ষণ অবধি ঠিক আছে।
#
# जाबत धरि हुनका पहिने रुकबाक लेल सूचित कयल जाइत अछि ताबत धरि ठीक अछि।
#
# আমি তাদের এখন জানিয়ে দিয়েছি যাতে ঢুকতে গেলে আপনাকে কোনও ঝামেলার মুখোমুখি না হতে হয়।
#
# हम आब हुनका सभ केँ सूचित कऽ देने छी जाहि सँ प्रवेश करय पर अहाँकेँ कोनो परेशानी नहि होअय।
#
# ঠিক আছে, এটা যাচাই করার জন্য আপনি আমাকে কোনও কাগজপত্র বা স্ক্রিনশট পাঠাতে পারবেন?
#
# ठीक अछि, की अहाँ एकरा सत्यापित करबाक लेल हमरा कोनो पेपर या स्क्रीनशॉट पठा सकैत छी?
#
# সমস্যা সৃষ্টির জন্য আমি দুঃখিত, কিন্তু এটা কোম্পানির নীতি।
#
# समस्या उत्पन्न करबाक लेल हमरा खेद अछि, मुदा ई कम्पनीक नीति अछि।
#
# আমার কাছে ক্যাম্পাস নির্দেশিকার একটা কপি রয়েছে যেখানে এটা বলা আছে।
#
# हमरा लग परिसरक दिशानिर्देशक प्रति अछि जाहिमे ई कहल गेल अछि।
#
# আমি এক্ষুনি আপনাকে হোয়াটসঅ্যাপে পাঠালাম।
#
# हम एखनहि अहाँकेँ वॉट्सऐप पर पठा देलहुँ।
#
# আচ্ছা, এটায় কাজ হওয়া উচিত।
#
# ठीक अछि, एहि पर काज करबाक चाही।
#
# ভবিষ্যতে সুবিধার জন্য আপনি ক্যাম্পাসে আমাদের পরিষেবা পেতে একটা অ্যাপ ব্যবহার করতে পারেন।
#
# भविष्यमे सुविधाक लेल अहाँ परिसरमे हमर सेवा प्राप्त करबाक लेल एकटा ऐपक उपयोग कऽ सकैत छी।
#
# এটির নাম ট্রাভা-গো এবং গুগল প্লে স্টোরে উপলব্ধ।
#
# एकर नाम ट्रावा-गो अछि आ ई गूगल प्ले स्टोर पर उपलब्ध अछि।
#
# এটা দারুণ কাজে আসবে।
#
# ई बहुत काज करत।
#
# আপনি কি হোস্টেলের অবস্থানের সঙ্গে পরিচিত?
#
# की अहाँ छात्रावासक स्थानसँ परिचित छी?
#
# আমি এলাকায় নতুন তাই মনে হয় আমার খুব একটা ধারণা নেই।
#
# हम एहि क्षेत्रमे नव छी तेँ एना प्रतीत होइत अछि जे हमरा बहुत किछु नहि बुझाइत अछि।
#
# তবে আমি নিশ্চিত, যে ড্রাইভার আপনার জন্য বরাদ্দ করা হবে, সে রাস্তাঘাট চিনবে।
#
# मुदा हमरा पक्का अछि जे जे चालक अहाँकेँ देल जायत ओ सड़ककेँ चिन्हैत रहत।
#
# আমি আপনাকে ঠিকানা পাঠিয়ে দেব পাছে সে যদি না জেনে থাকে।
#
# जँ ओ नहि जनैत छल तँ हम अहाँ केँ पता पठा सकैत छी।
#
# ভাড়া কি আগে থাকতে দিতে হবে নাকি গন্তব্যে পৌঁছানোর পর?
#
# की किराया पहिनेसँ देय अछि वा गंतव्य पर पहुँचलाक बाद?
#
# সেটা আপনার ইচ্ছা।
#
# ई अहाँक इच्छा अछि।
#
# আপনি চাইলে আগে দিয়ে দিতে পারেন বা পৌঁছনোর পরে।
#
# जँ अहाँ चाहैत छी तँ पहिने दऽ सकैत छी अथवा पहुँचलाक बाद दऽ सकैत छी।
#
# যদি গাড়িকে আপনার জন্য আপেক্ষা করতে হয় তাহলে অতিরিক্ত ভাড়া লাগবে।
#
# जँ कारकेँ अहाँक प्रतीक्षा करबाक आवश्यकता अछि तँ अतिरिक्त किरायाक आवश्यकता पड़त।
#
# তার কোনও প্রয়োজন পরবে না।
#
# हुनका कोनो वस्तुक आवश्यकता नहि रहत।
#
# আমি দশ মিনিটের মধ্যে তৈরি হয়ে যাব, তাই আশা করছি তার মধ্যে গাড়ি এসে যাবে।
#
# ...
#
# এখানে মশলাও প্রচুর তাই বেশিরভাগ খাবারেই মশলার পরিমাণ খুব বেশি থাকে।
#
# एतऽ मसल्ला सेहो बहुत अछि तेँ अधिकांश भोजनमे मसल्लाक मात्रा बहुत बेसी होइत अछि।
#
# লিট্টি কি আপনার সব চেয়ে প্রিয় পদ?
#
# की लिट्टी अहाँक सबसँ प्रिय पद अछि?
#
# লিট্টি আমার পছন্দের খাবারের মধ্যে একটা।
#
# लिट्टी हमर प्रिय भोजनमे सँ एक अछि।
#
# আমার প্রিয় বিহারী খাবার হল ছাতুর পরোটা।
#
# हमर प्रिय बिहारी व्यंजन छत्तर पराठा अछि।
#
# এটা একটা ভারতীয় টাকোর মতো দেখতে।
#
# ई एकटा भारतीय टाको जकाँ देखाइत अछि।
#
# আমি এটার কথা কখনও শুনিনি, কিন্তু এটা কি খুব স্বাস্থ্যকর?
#
# हम एकर विषयमे कहियो नहि सुनने छी, मुदा की ई बहुत स्वस्थ अछि?
#
# আরে হ্যাঁ! এটা একটা খুবই স্বাস্থ্যকর পদ।
#
# ओह हँ! ई बड्ड स्वस्थ भोजन अछि।
#
# এটা ছোলার ময়দা আর অন্যান্য শাকপাতা দিয়ে তৈরি করা হয়।
#
# ई पॉपकॉर्नक आटा आ अन्य तरकारीक पातसँ बनाओल जाइत अछि।
#
# এটার একটা খুব টকমতো স্বাদও আছে যার জন্য এটা আমার প্রিয়।
#
# एकर स्वाद सेहो बहुत बढ़िया अछि जाहि कारणेँ ई हमर प्रिय अछि।
#
# তোমার কথা বল, কেরলের খাবারের মধ্যে তোমার পছন্দের পদ কোনটা?
#
# अपन बात बताउ, केरलक भोजनमे अहाँक पसंदीदा व्यंजन कोन अछि?
#
# আপ্পাম আর স্ট্যু আমার পছন্দের।
#
# अप्पम आ स्टू हमर प्रिय अछि।
#
# এটা গেঁজিয়ে তোলা চালের গুঁড়ো দিয়ে তৈরি করা হয়। এটা মূলত একটা প্যানকেক যার ধারগুলো খাস্তা হয়।
#
# एकरा चाउरक चूर्णसँ बनाओल जाइत अछि। ई मुख्य रूपसँ एकटा पेनकेक अछि जकर धार क्रिस्प होइत अछि।
#
# ওহ, এটা সুস্বাদু শোনাচ্ছে।
#
# ओह, ई स्वादिष्ट लगैत अछि।
#
# আমাদের এটা আরও বেশি বার করা উচিত।
#
# हमरा सभ केँ ई बेसी बेर करबाक चाही।
#
# শুনছেন, এখানে কি কোনও ময়দা-ছাড়া খাবার পাওয়া যায়?
#
# सुनू, की एतऽ आटा रहित भोजन उपलब्ध अछि?
#
# আমি ডায়াবেটিসে ভোগা মানুষ আর আমার বন্ধুর ময়দাতে অ্যালার্জি আছে।
#
# हम मधुमेहसँ पीड़ित व्यक्ति छी आ हमर मित्रकेँ आटा सँ एलर्जी अछि।
#
# নিশ্চয়ই, আপনি কী খেতে আগ্রহী?
#
# अवश्य, अहाँकेँ की खयबाक रुचि अछि?
#
# আমি আশা করছিলাম যে আপনি আপনাদের কিছু খাবার নিয়ে পরামর্শ দিতে পারবেন।
#
# हमरा आशा छल जे अहाँ किछु खाद्य पदार्थक सुझाव दऽ सकय छी।
#
# আমি শুনেছি যে এই রেস্তরাঁয় খুব স্বাস্থ্যকর খাবার পাওয়া যায়।
#
# हम सुनने छी जे एहि रेस्तराँमे बहुत स्वस्थ भोजन उपलब्ध अछि।
#
# ময়দা-ছাড়া খাবার খুঁজছেন এমন গ্রাহকদের জন্য আমরা চাল, ভুট্টা, শণের বীজ আর বাজরার বিকল্প রাখি।
#
# आटा रहित भोजनक तलाशमे रहल ग्राहकक लेल हम चावल, मकई, भांगक बीज आ बाजराक विकल्प दैत छी।
#
# আমাদের অনেক রকমের স্যালাড আর স্মুদি-ও আছে।
#
# हमरा लग बहुत प्रकारक सलाद आ स्मूदी सेहो अछि।
#
# আমাদের একটা ডায়াবেটিকদের উপযোগী মেনুও রয়েছে।
#
# हमरासभ लग मधुमेहक लेल एकटा मेन्यू सेहो अछि।
#
# আমি একটা স্থানীয় খাবারের তালিকা খুঁজছিলাম যাতে ময়দা নেই।
#
# हम एकटा स्थानीय व्यंजनक सूची ताकैत रहलहुँ जाहिमे आटा नहि छल।
#
# মাশরুম ভাত কিম্বা চিকেন কিনোয়া বিরিয়ানির মতো কিছু।
#
# मशरूम चावल या चिकन किनोआ बिरयानी सन किछु।
#
# হ্যাঁ, এই বিকল্পগুলো এখানে পাওয়া যায়।
#
# हँ, ई विकल्प सभ एतऽ उपलब्ध अछि।
#
# আমাদের কিছু ময়দা-ছাড়া স্যুপের পদও আছে যেগুলো আপনি একবার খেয়ে দেখতে পারেন।
#
# हमरा लग किछु बिना आटा वाला सूप व्यंजन सेहो अछि जकरा अहाँ परख सकैत छी।
#
# ডায়াবেটিকদের উপযোগী মেনু থেকে আপনি কী পাওয়ার আশা রাখেন?
#
# मधुमेहक अनुकूल मेन्यूसँ अहाँ की प्राप्त करबाक आशा करैत छी?
#
# আমি একটা সাবুদানার খিচুড়ি আর একটা মাশরুম ব্রাউন রাইস নেব যেটার কথা আমি আগে বলেছিলাম।
#
# हम पहिने जे कहलनि ओकर तुलनामे हम एकटा साबूदाना खीचड़ी आ एकटा मशरूम ब्राउन राइस लेब।
#
# স্যুপের জন্য আপনার কী কী বিকল্প আছে?
#
# सूपक लेल अहाँ लग कोन-कोन विकल्प अछि?
#
# আমাদের একটা ফ্রেঞ্চ অনিয়ন সুপ রয়েছে যা ময়দা-ছাড়া।
#
# हमरा सभ लग एकटा फ्रेंच प्याजक सूप अछि जे आटा रहित अछि।
#
# আমরা একটা সুস্বাদু স্প্লিট পি স্যুপও বানাই।
#
# हमसभ एकटा स्वादिष्ट स्प्लिट पी सूप सेहो बनबैत छी।
#
# এরপর আমাদের রয়েছে ফো বো এবং আরেকটি পশ্চিম আফ্রিকান পিনাট বাটার স্যুপ।
#
# फेर हमरा सभ लग फो बो आ एकटा आओर पश्चिम अफ्रीकी पीनट बटर सूप अछि।
#
# ফ্রেঞ্চ অনিয়ন স্যুপটা আকর্ষণীয় শোনাচ্ছে তাই আমরা এটা দুটো নেব।
#
# फ्रेंच प्याजक सूप आकर्षक लगैत अछि तेँ हम ओकरा दू गोट लऽ लेताह।
#
# আমি সাধারণত মিষ্টিটা এড়িয়ে চলি কারণ ডায়াবেটিস- উপযোগী মিষ্টি খুঁজে পাওয়া কঠিন।
#
# हम सामान्यतः मिठाईसँ बचैत छी किएक तँ मधुमेहसँ सम्बन्धित मिठाई तकनाइ कठिन अछि।
#
# ওহ, চিন্তা করবেন না, আমাদের ডায়াবেটিক- উপযোগী মিষ্টির বিকল্পও রয়েছে।
#
# ओह, चिन्ता नहि करू, हमरा लग मधुमेहक अनुकूल मिठाईक विकल्प सेहो अछि।
#
# আপনি কম কার্ব-এর পিনাট বাটার কুকিজ কিংবা চকোলেট কিটো ফ্যাট বম্ব খেয়ে দেখতে পারেন।
#
# अहाँ कम कार्बयुक्त पीनट बटर कुकीज वा चॉकलेट कीटो फैट बॉम्ब्स खयबाक प्रयास कऽ सकैत छी।
#
# আমরা খুব ভাল প্রোটিন চিজকেকও বানাই।
#
# हमसभ बहुत नीक प्रोटीन चीजकेक सेहो बनबैत छी।
#
# আমি আমার ডায়াবেটিসের কারণ অনেকদিন চিজকেক খাইনি।
#
# हम अपन मधुमेहक कारण बहुत दिन धरि चीजकेक नहि खयलनि।
#
# আমি ওর জন্য প্রোটিন চিজকেক আর লো-কার্ব পিনাট বাটার কুকিজ নেব।
#
# हम ओकर लेल प्रोटीन चीजकेक आ लो-कार्ब पीनट बटर कुकीज लैत छी।
#
# এই রেস্তোরাঁটা চমৎকার।
#
# ई रेस्तराँ बड्ड बढ़िया अछि।
#
# প্রশংসার জন্য ধন্যবাদ।
#
# प्रशंसाक लेल धन्यवाद।
#
# আশা করি আপনি সময় বার করে গুগুলে আমাদের জন্য একটা রিভিউ দেবেন।
#
# हमरा आशा अछि जे अहाँ समय निकालि कऽ गूगल पर हमरा सभक लेल एकटा समीक्षा देब।
#
# আপনার যদি কিছু প্রয়োজন হয় অনুগ্রহ করে আমায় জানাবেন।
#
# जँ अहाँकेँ कोनो चीजक आवश्यकता अछि तँ कृपया हमरा बताउ।
#
# আমি নিশ্চয়ই একটা ভাল রিভিউ দেব আপনাদের।
#
# हम निश्चित रूपसँ अहाँकेँ एकटा नीक समीक्षा देब।
#
# স্যার, আমি কি ভিতরে আসতে পারি?
#
# श्रीमान, की हम भीतर आबि सकैत छी?
#
# হ্যাঁ, বসুন।
#
# हँ, बसू।
#
# আপনার জন্য আমি কী করতে পারি?
#
# हम अहाँक लेल की कऽ सकैत छी?
#
# আমার নাম আনন্দ যাদব।
#
# हमर नाम आनन्द यादव अछि।
#
# আমি আমার সেভিংস আকাউন্ট থেকে কিছু টাকা তুলতে চাই।
#
# हम अपन बचत खातासँ किछु पाई निकालय चाहैत छी।
#
# টাকা তোলার পদ্ধতি কি সেটা আমি ঠিক জানিনা।
#
# हमरा ठीक-ठीक पता नहि अछि कि पैसा उठयबाक तरीका की अछि।
#
# আপনি কি দয়া করে আমায় সাহায্য করতে পারেন?
#
# की अहाँ कृपया हमर सहायता कऽ सकैत छी?
#
# অবশ্যই, স্যার।
#
# बेशक, सर।
#
# প্রথমে এবং সবার আগে, আপনাকে টাকা তোলার ফর্মটা ভরতে হবে।
#
# सबसँ पहिने आ सबसँ महत्वपूर्ण बात ई अछि जे अहाँकेँ निकासी प्रपत्र भरय पड़त।
#
# অনুগ্রহ করে নিচের ঘরগুলোয় আপনার আকাউন্ট নম্বর, নাম, মোবাইল নম্বর আর ঠিকানা লিখুন।
#
# कृपया निम्नलिखित कक्षमे अपन खाता संख्या, नाम, मोबाइल नंबर आ पता दर्ज करू।
#
# ঠিক আছে। আমাকে কি এখানে সই করতে হবে?
#
# ठीक अछि। की हमरा एतऽ हस्ताक्षर करय पड़तैक?
#
# অবশ্যই। দয়া করে করুন।
#
# बेशक। कृपया करू।
#
# আপনি কত টাকা তুলতে চান?
#
# अहाँ कतेक निकालय चाहैत छी?
#
# আমায় ১,০০০০০ টাকা তুলতে হবে।
#
# हमरा 1,00,000 टाका निकालबाक अछि।
#
# দয়া করে শব্দে ও সংখ্যায় পরিমাণটা দিয়ে ফর্মটা ভর্তি করুন, স্যার।
#
# कृपया शब्द आ संख्या मे राशि के संग फॉर्म भरू, सर।
#
# উইথড্রয়াল ফর্মের নীচে আপনার নাম সই করতে ভুলবেন না।
#
# निकासी प्रपत्रक नीचाँ अपन नाम पर हस्ताक्षर करब सुनिश्चित करू।
#
# আচ্ছা। আমি এটা মনে রাখব।
#
# ठीक अछि। हम एकरा स्मरण करब।
#
# এর মধ্যে কোনটা টাকা তোলার কাউন্টার?
#
# एहिमेसँ कोनटा निकासी काउंटर अछि?
#
# স্যার, অনুগ্রহ করে কাউন্টার নম্বর ২-এর দিকে যান।
#
# श्रीमान, कृपया काउंटर नंबर 2 पर जाउ।
#
# কাউন্টারে যিনি আছেন তিনি গ্রাহকের অ্যাকাউন্ট নম্বর আর নাম নিশ্চিত করে নেবেন।
#
# काउंटर पर उपस्थित व्यक्ति ग्राहकक खाता संख्या आ नाम सुनिश्चित करत।
#
# আর আপনি আপনার টাকাটা পেয়ে যাবেন।
#
# आ अहाँ केँ अपन पाई भेटत।
#
# ধন্যবাদ!
#
# धन्यवाद!
#
# আমি কি আপনার জন্য আর কিছু করতে পারি?
#
# की हम अहाँक लेल आओर किछु कऽ सकैत छी?
#
# আমার আরও একটা সাহায্যের প্রয়োজন।
#
# हमरा एकटा आओर सहायताक आवश्यकता अछि।
#
# টাকা তোলার পর আমি কীভাবে জানব আমার অ্যাকাউন্টে কত টাকা বাকি আছে?
#
# पैसा निकाललाक बाद हम कोना जानि सकैत छी जे हमर खातामे कतेक टाका शेष अछि?
#
# স্যার, অনুগ্রহ করে কাউন্টারের কর্মীদের পাসবুকে ব্যালান্সের পরিমাণটা তুলে দিতে বলুন।
#
# श्रीमान, कृपया काउंटर पर कर्मचारीसभकेँ पासबुकमे शेष राशि जमा करय लेल कहू।
#
# ঠিক আছে! আপনাকে অনেক ধন্যবাদ।
#
# ठीक अछि! बहुत बहुत धन्यवाद।
#
# ওয়েলকাম স্যার!
#
# स्वागत अछि सर!
#
# মূল্যবান গ্রাহক হওয়ার জন্য ধন্যবাদ।
#
# बहुमूल्य ग्राहक होयबाक लेल धन्यवाद।
#
# আবার আসবেন।
#
# हम फेरसँ आबि रहल छी।
#
# আপনার খেলাধুলো নিয়ে ছবি পছন্দ?
#
# की अहाँकेँ अपन खेलक चित्र पसिन्न अछि?
#
# আরে যেই ছবিগুলোয় সত্যিকারের খেলোয়াড়দের গল্প বলে।
#
# अरे, एहन सिनेमा जे वास्तविक खिलाड़ीक कहानी कहैत अछि।
#
# ওগুলো বেশ অনুপ্রেরণা দেয়।
#
# ओ सभ बड्ड प्रेरित करैत अछि।
#
# 'মেরি কম' দেখার পর থেকে আমার এগুলো ভালো লাগতে শুরু করে।
#
# 'मैरी कॉम' देखलाक बाद हमरा ई पसिन्न पड़नाइ शुरू भऽ गेल।
#
# কী ভালো লেগেছিল ওটা দেখতে।
#
# ई देखबामे कतेक नीक लगैत छल।
#
# ওহ্ আমার দারুণ লাগে এই ছবিগুলো।
#
# ओह हमरा ई चित्र नीक लगैत अछि।
#
# আমার সবচেয়ে প্রিয় 'ভাগ মিলখা ভাগ'।
#
# हमर सबसँ प्रिय भाग मिल्खा भाग अछि।
#
# এটা দৌড়বিদ মিলখা সিংহ-কে নিয়ে ২০১৩-র ছবি।
#
# ई 2013क एकटा फिल्म अछि जाहिमे धावक मिल्खा सिंहकेँ देखाओल गेल अछि।
#
# আপনি জানেন সেই লোকটা কী দারুণ?
#
# अहाँ जनैत छी जे ओ आदमी कतेक नीक अछि?
#
# তিনি দ্য ফ্লাইং শিখ নামেও পরিচিত!
#
# हुनका द फ्लाइंग सिखक नामसँ सेहो जानल जाइत अछि।
#
# ওহ্ আমার দারুণ লাগে লোকটাকে।
#
# ओह हमरा बड्ड नीक लगैत अछि ओ आदमी।
#
# ইনিই একমাত্র ক্রীড়াবিদ, যিনি এশিয়ান গেমস এবং কমনওয়েলথ গেমসের ৪০০ মিটারে সোনা জিতেছিলেন।
#
# ओ एकमात्र एथलीट छथि जे एशियाई खेल आ राष्ट्रमण्डल खेलमे 400 मीटर दौड़मे स्वर्ण पदक जीतने छथि।
#
# কি কুল না ব্যাপারটা?
#
# की ई नीक बात नहि अछि?
#
# তিনি ১৯৫৮ ও ১৯৬২-এর এশিয়ান গেমসেও সোনার পদক জিতেছিলেন।
#
# ओ 1958 आ 1962क एशियाई खेलमे स्वर्ण पदक सेहो जितलनि।
#
# আমি একদিন ওঁর মতন হতে চাই।
#
# हम एक दिन हुनका जकाँ बनय चाहैत छी।
#
# উনার একটা পদ্মশ্রী আছে।
#
# हुनका लग पद्मश्री अछि।
#
# ওঁর মতন একজন দুর্দান্ত ক্রীড়াবিদ হয়ে যাওয়ার পরে আমিও তা পেতে চাই।
#
# हम सेहो हुनका जकाँ एकटा महान एथलीट बनलाक बाद ई प्राप्त करय चाहैत छी।
#
# আর সেই দৌড়টা যেখানে তিনি চতুর্থ হয়েছিলেন?
#
# आ ओ दौड़ जतय ओ चौथा स्थान पर रहलाह?
#
# ১৯৬০-এর অলিম্পিক গেমসের ৪০০ মিটারের ফাইনালটা?
#
# 1960क ओलम्पिक खेलमे 400 मीटरक फाइनल?
#
# আমার মনে হয় এটার জন্যই ওঁকে সবচেয়ে বেশি মনে রাখা হয়েছে।
#
# हमर विचार अछि जे एहि कारणेँ हुनका सबसँ बेसी याद कयल जायत।
#
# আমাকে একবার ওঁর বিষয়ে একটা প্রজেক্ট রিপোর্ট লিখতে হয়েছিল।
#
# हमरा एक बेर हुनका पर एकटा परियोजना रिपोर्ट लिखय पड़लनि।
#
# অনেক পড়েছিলাম তখন ওঁর সম্পর্কে।
#
# तखन हम हुनका विषयमे बहुत किछु पढ़ि चुकल छलहुँ।
#
# সেই সময় তিনি চতুর্থ হয়ে ভারতীয় জাতীয় রেকর্ড গড়েছিলেন, যা ৪০ বছর পর্যন্ত ভাঙেনি।
#
# ओहि समय ओ भारतीय राष्ट्रीय रिकॉर्ड बनयबाक लेल चौथा स्थान पर छलाह, जकरा ओ 40 साल धरि नहि तोड़लनि।
#
# আমার বড় হয়ে ওঠার সময়টায় আমি ওঁর সম্পর্কে অনেক শুনেছি।
#
# जखन हम पैघ भेलहुँ तँ हम हुनकर विषयमे बहुत किछु सुनने छी।
#
# আমার বাবা একজন অন্ধ ভক্ত ছিলেন।
#
# हमर पिता आन्हर भक्त छलाह।
#
# আমি তাঁর আত্মজীবনীও পড়েছি।
#
# हम हुनकर आत्मकथा सेहो पढ़ि चुकल छी।
#
# এটা পড়ার পরই আমার মনে হয়েছিল ছবিটা দেখব।
#
# एकरा पढ़लाक बाद हमरा लगैत छल जे हम फिल्म देखब।
#
# দেখাটা একদম সার্থক ছিল।
#
# ई देखबाक लेल एकदम सही छल।
#
# ছবিটা অনেক পুরস্কারও পেয়েছে।
#
# फिल्मकेँ बहुत रास पुरस्कार सेहो भेटलनि।
#
# ফারহান আখতার দারুণ করেছে।
#
# फरहान अख्तर बड्ड नीक काज कयने छथि।
#
# বেশ কুল হবে ব্যাপারটা যদি মিলখা সিংহের মতন একজন মহান ক্রীড়াবিদ হওয়া যায়।
#
# अगर मिल्खा सिंह सन महान खिलाड़ी बनि सकैत छथि तँ ई बड्ड सुखद होयत।
#
# হ্যালো, এটা কি জয়পুর সিটি প্যালেস?
#
# नमस्कार, की ई जयपुर सिटी पैलेस अछि?
#
# হ্যাঁ, আমি কিভাবে আপনাকে সাহায্য করতে পারি?
#
# हँ, हम अहाँक कोना मदति कऽ सकैत छी?
#
# আমি ভেরা ব্র্যাণ্ড থেকে যোগাযোগ করছি।
#
# हम वेरा ब्रांडसँ सम्पर्क कऽ रहल छी।
#
# আমরা চেন্নাই ভিত্তিক একটি আন্তর্জাতিক বিলাসবহুল ব্র্যাণ্ড।
#
# हम चेन्नई स्थित एकटा अन्तर्राष्ट्रीय विलासिता ब्रांड छी।
#
# আমি ছবি তোলার জন্য প্রাসাদে প্রবেশ করার অনুরোধ জানাতে যোগাযোগ করছি।
#
# हम सम्पर्क कऽ रहल छी जाहि मे हम महल मे प्रवेश करय के अनुरोध कऽ रहल छी जाहि सँ फोटो लेल जा सकय।
#
# আমরা একটি নতুন জিনিস প্রকাশ করছি।
#
# हम सभ एकटा नव बात प्रकट कऽ रहल छी।
#
# আচ্ছা, সেটার ব্যবস্থা করে দেওয়া যাবে।
#
# ठीक अछि, एकर व्यवस्था कयल जा सकैत अछि।
#
# আমি কি আপনার নামটা জানতে পারি?
#
# की हम अहाँक नाम जानि सकैत छी?
#
# আমার নাম হল অনন্ত। কোনও পরিচয়পত্র প্রয়োজন আপনার?
#
# हमर नाम अनन्त अछि। की अहाँकेँ कोनो पहचान पत्रक आवश्यकता अछि?
#
# আমাদের বেশ কিছু কাগজপত্র দরকার।
#
# हमरा सभ केँ बहुत रास कागजी कार्रवाईक जरूरत अछि।
#
# এক, একটা বৈধ প্রমাণপত্র যে কোম্পানিটির অস্তিত্ব রয়েছে।
#
# पहिल, एकटा वैध प्रमाण जे कम्पनीक अस्तित्व अछि।
#
# দ্বিতীয়, এর সঙ্গে জড়িত সব সদস্যদের একটি তালিকা, সঙ্গে তাদের পরিচয়পত্র।
#
# दोसर, एहिमे सम्मिलित सभ सदस्यक सूची, सङ्गहि हुनक पहचान पत्र।
#
# এবং দায়িত্বে থাকা ব্যক্তির পরিচয়ের প্রমাণ।
#
# आ प्रभारी व्यक्तिक पहिचानक प्रमाण।
#
# কাগজপত্রগুলো যদি আপনাকে মেইল করে দি, তাহলে হবে তো?
#
# यदि अहाँ कागज-पत्र अहाँकेँ मेल करैत छी तँ की होयत?
#
# হ্যাঁ, তবে শুটের দিনে আমরা পরিচয়ের প্রমাণপত্র দেখতে চাইব।
#
# हँ, मुदा शूटिंगक दिन हम पहिचानक प्रमाण पत्र देखय चाहैत छी।
#
# নিশ্চয়ই, আমি বুঝতে পারছি।
#
# बेशक, हम बुझैत छी।
#
# চার্জ ও ভাড়া কত?
#
# शुल्क आ किराया कतेक अछि?
#
# প্যাকেজের উপর ভিত্তি করে ভারতীয় নাগরিক বা বাসিন্দাদের ভাড়া হল ২০০ বা ৩০০ টাকা।
#
# पैकेजक आधार पर भारतीय नागरिक या निवासीक लेल किराया 200 या 300 रुपया अछि।
#
# সংগ্রহশালার প্যাকেজে রয়েছে প্রাসাদের সবকটা কোর্ট ও গ্যালারি এবং ট্রাইপড ছাড়া ক্যামেরা।
#
# संग्रहालय पैकेजमे महलक सभ कोर्ट आ गैलरी, आ बिना ट्राइपोडक कैमरा शामिल अछि।
#
# কম্পোজিট প্যাকেজে এটা থাকে সঙ্গে জয়গড় এবং রাজকীয় সেনোটাফগুলি।
#
# कम्पोजिट पैकेजमे एकरा जयगढ़ आ शाही स्मारकक संग शामिल कयल गेल अछि।
#
# বিদেশীদের এই কম্পোজিট প্যাকেজের জন্য ৭০০ টাকা চার্জ করা হবে।
#
# विदेशीकेँ एहि मिश्रित पैकेजक लेल 700 रुपया लेल जायत।
#
# প্রাসাদে রাতে প্রবেশ করতে পারব আমরা?
#
# की हम रातिमे महलमे प्रवेश कऽ सकैत छी?
#
# করতে পারবেন, সেটা অন্য প্যাকেজ।
#
# भऽ सकैत अछि, ई दोसर पैकेज अछि।
#
# সেটা আপনার ভারতীয়দের জন্য ৫০০ টাকা এবং বিদেশীদের জন্য ১০০০ টাকা পড়বে।
#
# ई अहाँक भारतीयक लेल 500 टाका आ विदेशीक लेल 1000 टाका होयत।
#
# বিশেষ কিছু টিকিটও পাওয়া যায় যেটা আপনাকে একান্ত প্রবেশাধিকার দেবে।
#
# किछु विशेष टिकट सेहो उपलब्ध अछि जे अहाँकेँ विशेष पहुँच प्रदान करत।
#
# আরও বিস্তারিত জানার জন্য আপনি আমাদের ওয়েবসাইটটা দেখতে পারেন।
#
# अधिक जानकारी लेल अहाँ हमर वेबसाइट पर जा सकैत छी।
#
# সপ্তাহের মাঝখানে যদি কেউ আসে এবং বুকিং করে যায়, সেটা কি হবে?
#
# जँ केओ सप्ताहक मध्यमे अबैत अछि आ बुक करैत अछि तँ की होयत?
#
# হ্যাঁ, তা-ও ঠিক আছে।
#
# हँ, ठीक अछि।
#
# যোগাযোগ করার জন্য ধন্যবাদ।
#
# सम्पर्क करबाक लेल धन्यवाद।
#
# হাই বিষ্ণু, কি করছো আজকাল?
#
# नमस्कार विष्णु, आइकालमे अहाँ की कऽ रहल छी?
#
# সাম্প্রতিক কোনও বাইক রাইডে গেছিলে নাকি?
#
# की अहाँ हालहिमे कोनो बाइक राइड पर गेल छी?
#
# তোমার কয়েকটা ছবি দেখলাম।
#
# हम अहाँक किछु फोटो देखलहुँ।
#
# না, ওগুলো বহুকাল আগের অন্য এক রাইডের ছবি।
#
# नहि, ई बहुत पहिनेक एकटा आओर सवारीक चित्र अछि।
#
# সারা সপ্তাহটা খুব ব্যস্ত কাটায় রাইডের জন্য সময়ই বের করতে পারিনি।
#
# पूरा सप्ताह बड्ड व्यस्त रहलहुँ, हम सवारी लेल समय नहि निकालि सकलाह।
#
# কিন্তু, এই উইকেণ্ডে যাচ্ছি।
#
# मुदा, हम एहि सप्ताहान्तमे जा रहल छी।
#
# তোমার খবর কি; তোমার গানের প্র্যাক্টিস করছো তো?
#
# अहाँक की खबर अछि; अपन गीतक अभ्यास कऽ रहल छी?
#
# হ্যাঁ, একটুও খালি সময় পেলেই করছি।
#
# हँ, हम मात्र तखन करैत छी जखन हमरा लग किछु खाली समय रहैत अछि।
#
# আমার দিনগুলোও ব্যস্ততায় ভরা, জানো।
#
# हमर दिन सेहो व्यस्त अछि, अहाँ जनैत छी।
#
# রেওয়াজ করার সময়টুকুও তো রোজ বার করতে পারি না।
#
# हम रोज रिवाज़ करबाक लेल समय सेहो नहि निकालि सकैत छी।
#
# যাই হোক, এই উইকেণ্ডে কি সত্যিই তুমি খালি আছো?
#
# बहरहाल, की एहि सप्ताहान्तमे अहाँ वास्तवमे खाली छी?
#
# রাইডে যাওয়ার সময় বার করবে কি করে?
#
# जखन अहाँ सवारी करय जा रहल छी तखन बार केना करब?
#
# আসলে কয়েকদিন ধরে ওভারটাইম করে আমার টার্গেট পূরণ করেছি।
#
# असलमे किछु दिन धरि ओवरटाइम कऽ अपन लक्ष्य पूरा कयलहुँ।
#
# তাই এই উইকেণ্ডে খালি আছি।
#
# तेँ हम एहि सप्ताहान्तमे खाली छी।
#
# নিজেকে চাঙ্গা করার সময়ের ভীষণ প্রয়োজন আমার।
#
# हमरा स्वयंकेँ तरोताजा करबाक लेल समयक बड्ड आवश्यकता अछि।
#
# একমাত্র তোমার শখ অনুসরণ করলেই সেটা সম্ভব, তাই না?
#
# ई केवल तखन सम्भव अछि जखन अहाँ अपन शौकक पालन करैत छी, सही नै?
#
# হ্যাঁ, ঠিক বলেছো।
#
# हँ, अहाँ सही छी।
#
# নিজের জন্য কিছুটা সময় আমারও দরকার।
#
# हमरा अपन लेल सेहो किछु समय चाही।
#
# এই শুক্রবার একটা গানের প্রতিযোগিতায় অংশগ্রহণ করার কথাও ভাবছি।
#
# हम एहि शुक्रदिन एकटा गीत प्रतियोगितामे भाग लेबाक बारेमे सेहो सोच रहल छी।
#
# আমার পছন্দের কাজের সঙ্গে যুক্ত হওয়ায় সাহায্য করবে বলে আশা করি।
#
# आशा अछि जे जे काज हमरा पसिन्न अछि ताहि सँ जुड़ब मदति करत।
#
# এত ব্যস্ততার মধ্যেও তোমার শখ অনুসরণ করার সময় বের করো কি করে বলো তো?
#
# कतेक व्यस्तता के बीच अहाँ अपन शौक के पालन करै लेल समय कोना निकालि सकैत छी?
#
# কাজ শুরুর আগে প্রতিদিন সকালে রেওয়াজে বসার চেষ্টা করি।
#
# हम काज शुरू करबासँ पहिने रोज भोरे रेवेजमे बेसबाक कोशिश करैत छी।
#
# আর কাজ ফেলে না রাখার চেষ্টা করি।
#
# हम प्रयास करैत छी जे आब काज नहि छोड़ि दियौक।
#
# নিজের পছন্দের কাজগুলো করার জন্য কিছুটা সময় যাতে পাই।
#
# ताकि अहाँ केँ अपन पसंदक काज करय लेल किछु समय भेटय।
#
# সেটা করলে, উইকেণ্ডগুলো গান শুনে আর প্র্যাক্টিস করে কাটাতে পারি।
#
# एना कयलासँ हम सप्ताहान्तमे गीत सुनैत आ अभ्यास करैत रहि सकैत छी।
#
# আমিও একদম এরকমই করার চেষ্টা করি।
#
# हम सेहो ठीक ओही करबाक कोशिश करैत छी।
#
# কিন্তু গত কয়েকটা সপ্তাহ ভীষণ ব্যস্ততায় কেটেছে।
#
# मुदा अगिला किछु सप्ताह बड्ड व्यस्त रहल अछि।
#
# তাও এই উইকেণ্ডেটা বের করতে পেরেছি।
#
# हम एहि सप्ताहान्तकेँ सेहो निकालबामे सफल रहलहुँ।
#
# কি ধরনের গানের প্রতিযোগিতায় অংশগ্রহণ করছো?
#
# अहाँ कोन प्रकारक गीत प्रतियोगितामे भाग लऽ रहल छी?
#
# এটা এক ধরনের ইণ্টার-অফিস প্রতিযোগিতা।
#
# ई एक प्रकारक अन्तर-कार्यालय प्रतियोगिता अछि।
#
# এই প্রতিযোগিতাটায় আমি আমার অফিসের প্রতিনিধিত্ব করবো।
#
# हम एहि प्रतियोगितामे अपन कार्यालयक प्रतिनिधित्व करब।
#
# এটা নিয়ে আমি খুবই উত্তেজিত।
#
# हम एकरा लेल बड्ड उत्साहित छी।
#
# দারুণ, অবশ্যই অংশগ্রহণ করা উচিত তোমার।
#
# बढ़िया अछि, निश्चित रूपसँ अहाँकेँ एहिमे भाग लेबाक चाही।
#
# শুভ কামনা জানালাম।
#
# हम शुभ कामना व्यक्त कयलहुँ।
#
# অনেক ধন্যবাদ।
#
# बहुत बहुत धन्यवाद।
#
# তোমার যাত্রাও সুরক্ষিত হোক।
#
# अहाँक यात्रा सेहो सुरक्षित रहत।
#
# ধন্যবাদ, লেলিনা।
# धन्यवाद, लेलिना।

# %%
# Create a reference list for translated language : Maithili Language
original_sent = []

# Open the file and read each line
with open('IN22_testset/conv/test.mai_Deva', 'r') as f:
    for line in f:
        original_sent.append([line])

# %%
from datasets import load_metric

# Load the BLEU metric using the 'sacrebleu' implementation from the datasets library
metric = load_metric("sacrebleu")

# Compute the BLEU score by comparing the predicted translations with the original reference sentences
bleu_score = metric.compute(predictions = mai_sent, references=original_sent)

for key, value in bleu_score.items():
    print(f"{key}: {value}")
# Out:
# score: 14.646765849868627
# counts: [7469, 2968, 1372, 627]
# totals: [16506, 15003, 13501, 12015]
# precisions: [45.250212044105176, 19.78271012464174, 10.162210206651359, 5.218476903870163]
# bp: 0.9922752346995671
# sys_len: 16506
# ref_len: 16634

# %%
from datasets import load_metric

# Load the ROUGE metric using the 'rouge' implementation from the datasets library
rouge = load_metric("rouge")

# Compute the ROUGE score by comparing the first 200 predicted translations with the first 200 reference sentences
rouge_score = rouge.compute(predictions=mai_sent, references=original_sent)

# Print out each component of the ROUGE score
for key, value in rouge_score.items():
    print(f"{key}: {value}")
# Out:
# rouge1: AggregateScore(low=Score(precision=0.0, recall=0.0, fmeasure=0.0), mid=Score(precision=0.0, recall=0.0, fmeasure=0.0), high=Score(precision=0.0, recall=0.0, fmeasure=0.0))
# rouge2: AggregateScore(low=Score(precision=0.0, recall=0.0, fmeasure=0.0), mid=Score(precision=0.0, recall=0.0, fmeasure=0.0), high=Score(precision=0.0, recall=0.0, fmeasure=0.0))
# rougeL: AggregateScore(low=Score(precision=0.0, recall=0.0, fmeasure=0.0), mid=Score(precision=0.0, recall=0.0, fmeasure=0.0), high=Score(precision=0.0, recall=0.0, fmeasure=0.0))
# rougeLsum: AggregateScore(low=Score(precision=0.0, recall=0.0, fmeasure=0.0), mid=Score(precision=0.0, recall=0.0, fmeasure=0.0), high=Score(precision=0.0, recall=0.0, fmeasure=0.0))

# %%
from sacrebleu import corpus_bleu

# Calculate the BLEU score by importing corpus_bleu from sacrebleu package
bleu_score = corpus_bleu(mai_sent, original_sent)

# Print the BLEU score
print(f"BLEU Score: {bleu_score.score}")
# Out:
# BLEU Score: 30.739407647563215
